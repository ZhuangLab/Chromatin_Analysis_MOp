# %% [raw]
# This code analyzes the bulk RNA sequencing data from the Mecp2 R306C condition from Boxer et al., 2020

# %%
import os
import pickle as pkl

from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
from pydeseq2.utils import load_example_data

import pandas as pd
import numpy as np

# %% [markdown]
# # Load data

# %%
ko_file = 'GSE128178_10WT_10R306C_whole_cell_RNAseq_exon_counts.txt'
df_count = pd.read_csv(ko_file, sep='\t', index_col=0)
count_df = df_count.transpose()
count_df
# Out:
# Gene_name  Xkr4  Rp1  Sox17  Mrpl15  Lypla1  Tcea1  Rgs20  Atp6v1h  Oprk1  \
# WT_1        698    1     41     502     180    123    290     2675     74
# WT_2        578    1     36     419     233    117    234     2580     65
# WT_3        728    2     66     601     278    176    360     3177     89
# WT_4        765    1     64     562     266    169    335     3191     89
# WT_5        906    2     62     527     304    195    265     2936     99
# WT_6        718    2     34     480     241    138    244     2575     97
# WT_7        868    1     53     568     351    208    387     3827    100
# WT_8        932    3     61     525     317    210    336     3639    110
# WT_9        873    1     73     490     325    223    363     3475    143
# WT_10      1009    0     77     563     428    222    360     3690    145
# R306C_1     612    1     73     548     277    181    272     3046     58
# R306C_2     609    0     45     563     253    139    212     2625     65
# R306C_3     585    3     71     568     277    161    275     3069     73
# R306C_4     685    1     71     669     358    202    276     3039     75
# R306C_5     704    2     96     627     262    155    222     2860     68
# R306C_6     685    3     65     635     304    161    243     2872     54
# R306C_7     767    2     74     553     404    200    336     3576     87
# R306C_8     725    1     68     503     294    189    251     3064     74
# R306C_9     658    6     98     588     409    231    249     3096     91
# R306C_10    966    1     65     563     453    269    385     3898    105
#
# Gene_name  Npbwr1  ...  Gm20871  Gm20823  Gm20736  Gm20852  Ssty2  Gm20816  \
# WT_1           12  ...        0        0        0        0      0        0
# WT_2           31  ...        0        0        0        0      0        0
# WT_3           37  ...        0        0        0        0      0        0
# WT_4           38  ...        0        0        0        0      0        0
# WT_5           20  ...        0        0        0        0      0        0
# WT_6           21  ...        0        0        0        0      0        0
# WT_7           35  ...        0        0        0        0      0        0
# WT_8           34  ...        0        0        0        0      0        0
# WT_9           44  ...        0        0        0        0      0        0
# WT_10          35  ...        0        0        0        0      0        0
# R306C_1        10  ...        0        0        0        0      0        0
# R306C_2         8  ...        0        0        0        0      0        0
# R306C_3         9  ...        0        0        0        0      0        0
# R306C_4        16  ...        0        0        0        0      0        0
# R306C_5         8  ...        0        0        0        0      0        0
# R306C_6        19  ...        0        0        0        0      0        0
# R306C_7        16  ...        0        0        0        0      0        0
# R306C_8        18  ...        0        0        0        0      0        0
# R306C_9         7  ...        0        0        0        0      0        0
# R306C_10       14  ...        0        0        0        0      0        0
#
# Gene_name  Gm20867  Gm20806  Gm20917  Gm20854
# WT_1             0        0        0        0
# WT_2             0        0        0        0
# WT_3             0        0        0        0
# WT_4             0        0        0        0
# WT_5             0        0        0        0
# WT_6             0        0        0        0
# WT_7             0        0        0        0
# WT_8             0        0        0        0
# WT_9             0        0        0        0
# WT_10            0        0        0        0
# R306C_1          0        0        0        0
# R306C_2          0        0        0        0
# R306C_3          0        0        0        0
# R306C_4          0        0        0        0
# R306C_5          0        0        0        0
# R306C_6          0        0        0        0
# R306C_7          0        0        0        0
# R306C_8          0        0        0        0
# R306C_9          0        0        0        0
# R306C_10         0        0        0        0
#
# [20 rows x 24500 columns]

# %%
samples = count_df.index.values

genotype = []
for sample in samples:
    genotype.append(sample.split('_')[0])

clinical_df = pd.DataFrame({'sample':samples, 'genotype':genotype})
clinical_df.set_index('sample', inplace=True)
clinical_df
# Out:
#          genotype
# sample
# WT_1           WT
# WT_2           WT
# WT_3           WT
# WT_4           WT
# WT_5           WT
# WT_6           WT
# WT_7           WT
# WT_8           WT
# WT_9           WT
# WT_10          WT
# R306C_1     R306C
# R306C_2     R306C
# R306C_3     R306C
# R306C_4     R306C
# R306C_5     R306C
# R306C_6     R306C
# R306C_7     R306C
# R306C_8     R306C
# R306C_9     R306C
# R306C_10    R306C

# %% [markdown]
# # Calculate DEG

# %%
### filter by gene count
count_thresh = 100
gene_average = np.average(count_df, axis=0)
sel_genes = count_df.columns[np.where(gene_average>=count_thresh)]
count_df_filtered = count_df.loc[:, sel_genes]

# %%
dds = DeseqDataSet(
            counts=count_df_filtered,
            clinical=clinical_df,
            design_factors="genotype",  # compare samples based on the "condition"
            refit_cooks=True,
            n_cpus=16,
        )

# %%
dds.deseq2()
stat_res = DeseqStats(dds, n_cpus=16)

stat_res.summary()
result_df = stat_res.results_df
# Out:
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 4.15 seconds.
#
# Fitting dispersion trend curve...
# ... done in 2.60 seconds.
#
# Fitting MAP dispersions...
# ... done in 4.58 seconds.
#
# Fitting LFCs...
# ... done in 0.50 seconds.
#
# Refitting 4 outliers.
#
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.00 seconds.
#
# Running Wald tests...
# ... done in 0.51 seconds.
#
# Log2 fold change & Wald test p-value: genotype WT vs R306C
#              baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# Gene_name
# Xkr4       751.030518        0.270700  0.066422  4.075448  0.000046  0.001015
# Mrpl15     551.861938       -0.084139  0.046197 -1.821317  0.068559  0.262252
# Lypla1     308.190002       -0.108699  0.116376 -0.934031  0.350288  0.661352
# Tcea1      181.791443       -0.027427  0.100940 -0.271719  0.785838  0.926273
# Rgs20      293.572327        0.286871  0.082687  3.469370  0.000522  0.007408
# ...               ...             ...       ...       ...       ...       ...
# Spry3      208.366119        0.096276  0.104554  0.920831  0.357138  0.667065
# Kdm5d      321.656860       -0.114856  0.056458 -2.034354  0.041916  0.192379
# Eif2s3y    129.211060        0.128836  0.104560  1.232172  0.217885  0.517453
# Uty        349.299622       -0.036228  0.075395 -0.480509  0.630865  0.854889
# Ddx3y      453.866852       -0.133792  0.112420 -1.190111  0.234003  0.539211
#
# [11162 rows x 6 columns]

# %%
result_df['log2FoldChange'] = -result_df['log2FoldChange']

# %% [markdown]
# # Add radial position

# %%
df_gene = pd.read_csv(r'../scRNA_Greenberg/gene_info.csv', index_col=0)
df_gene['position'] = (df_gene['start'] + df_gene['end'])/2
df_gene.head()
# Out:
#             gene    chr      start        end     position
# 0  0610006L08Rik   chr7   74818817   74853813   74836315.0
# 1  0610007P14Rik  chr12   85815447   85824550   85819998.5
# 2  0610009B22Rik  chr11   51685385   51688874   51687129.5
# 3  0610009E02Rik   chr2   26445695   26459390   26452542.5
# 4  0610009L18Rik  chr11  120348677  120351190  120349933.5

# %%
df_rp = pd.read_csv(r"E:\DNA_analysis\Postanalysis_MeCP2\radial_position\all_rp_bulk_600pts_MOp_data.csv", 
                    index_col=0)
df_rp['chr'] = df_rp['loci_name'].apply(lambda x: x.split('_')[0])
df_rp['start'] = df_rp['loci_name'].apply(lambda x: int(x.split('_')[1]))
df_rp['end'] = df_rp['loci_name'].apply(lambda x: int(x.split('_')[2]))
df_rp['gene_position'] = (df_rp['start'] + df_rp['end'])/2
df_rp.head()
# Out:
#               loci_name   norm_RP   chr    start      end  gene_position
# 0  chr1_3742742_3759944  0.816454  chr1  3742742  3759944      3751343.0
# 1  chr1_6245958_6258969  0.800965  chr1  6245958  6258969      6252463.5
# 2  chr1_8740008_8759916  0.816597  chr1  8740008  8759916      8749962.0
# 3  chr1_9627926_9637875  0.793970  chr1  9627926  9637875      9632900.5
# 4  chr1_9799472_9811359  0.786175  chr1  9799472  9811359      9805415.5

# %%
rps = []

for i, row in df_gene.iterrows():
    df = df_rp[df_rp['chr']==row['chr']].copy()
    if len(df)>0:
        df['distance'] = np.abs(df['gene_position']-row['position'])
        df.sort_values('distance', inplace=True)
        if df['distance'].values[0]>=3000000:
            rps.append(-1)
        else:
            rps.append(df['norm_RP'].values[0])
    else:
        rps.append(-1)
        
df_gene['radial_position'] = rps

# %%
gene_to_rp = {gene:rp for (gene, rp) in zip(df_gene['gene'].values, df_gene['radial_position'].values)}

result_df['gene'] = result_df.index.values
result_df['radial_position'] = result_df['gene'].apply(lambda x: gene_to_rp[x] if x in gene_to_rp.keys() else -1)
result_df
# Out:
#              baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  \
# Gene_name
# Xkr4       751.030518       -0.270700  0.066422  4.075448  0.000046  0.001015
# Mrpl15     551.861938        0.084139  0.046197 -1.821317  0.068559  0.262252
# Lypla1     308.190002        0.108699  0.116376 -0.934031  0.350288  0.661352
# Tcea1      181.791443        0.027427  0.100940 -0.271719  0.785838  0.926273
# Rgs20      293.572327       -0.286871  0.082687  3.469370  0.000522  0.007408
# ...               ...             ...       ...       ...       ...       ...
# Spry3      208.366119       -0.096276  0.104554  0.920831  0.357138  0.667065
# Kdm5d      321.656860        0.114856  0.056458 -2.034354  0.041916  0.192379
# Eif2s3y    129.211060       -0.128836  0.104560  1.232172  0.217885  0.517453
# Uty        349.299622        0.036228  0.075395 -0.480509  0.630865  0.854889
# Ddx3y      453.866852        0.133792  0.112420 -1.190111  0.234003  0.539211
#
#               gene  radial_position
# Gene_name
# Xkr4          Xkr4         0.816454
# Mrpl15      Mrpl15         0.816454
# Lypla1      Lypla1         0.816454
# Tcea1        Tcea1         0.816454
# Rgs20        Rgs20         0.816454
# ...            ...              ...
# Spry3        Spry3        -1.000000
# Kdm5d        Kdm5d        -1.000000
# Eif2s3y    Eif2s3y        -1.000000
# Uty            Uty        -1.000000
# Ddx3y        Ddx3y        -1.000000
#
# [11162 rows x 8 columns]

# %%
result_df = result_df[result_df.radial_position!=-1].copy()
result_df
# Out:
#               baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Gene_name
# Xkr4        751.030518       -0.270700  0.066422  4.075448  0.000046
# Mrpl15      551.861938        0.084139  0.046197 -1.821317  0.068559
# Lypla1      308.190002        0.108699  0.116376 -0.934031  0.350288
# Tcea1       181.791443        0.027427  0.100940 -0.271719  0.785838
# Rgs20       293.572327       -0.286871  0.082687  3.469370  0.000522
# ...                ...             ...       ...       ...       ...
# Frmpd4     1551.674072       -0.102684  0.081466  1.260459  0.207504
# Msl3        287.475006       -0.042306  0.071778  0.589403  0.555591
# Arhgap6     112.292542        0.124587  0.101002 -1.233504  0.217388
# Hccs        248.675049       -0.065991  0.115512  0.571289  0.567804
# Mid1        120.590050        0.272897  0.126091 -2.164287  0.030442
#
#                padj     gene  radial_position
# Gene_name
# Xkr4       0.001015     Xkr4         0.816454
# Mrpl15     0.262252   Mrpl15         0.816454
# Lypla1     0.661352   Lypla1         0.816454
# Tcea1      0.926273    Tcea1         0.816454
# Rgs20      0.007408    Rgs20         0.816454
# ...             ...      ...              ...
# Frmpd4     0.504719   Frmpd4         0.813251
# Msl3       0.816044     Msl3         0.813251
# Arhgap6    0.517194  Arhgap6         0.813251
# Hccs       0.822618     Hccs         0.813251
# Mid1       0.155371     Mid1         0.797202
#
# [10848 rows x 8 columns]

# %%
result_df.to_csv(r'resources\Boxer_Mecp2_R306C_result_df_all_Rp.csv')
