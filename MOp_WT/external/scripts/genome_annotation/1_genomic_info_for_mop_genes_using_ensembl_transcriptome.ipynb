# %% [markdown]
# # 1. load required packages

# %% [markdown]
# The link to get [ImageAnalysis3](https://github.com/zhengpuas47/ImageAnalysis3)
#
# or the Zhuang lab archived [source_tools](https://github.com/ZhuangLab/Chromatin_Analysis_2020_cell/tree/master/sequential_tracing/source)

# %%
# %run "C:\Users\shiwei\Documents\ImageAnalysis3\required_files\Startup_py3.py"
sys.path.append(r"C:\Users\shiwei\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast

import pandas as pd

# library design specific tools
from ImageAnalysis3.library_tools import LibraryDesigner as ld
from ImageAnalysis3.library_tools import LibraryTools as lt
# biopython imports
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio.Blast import NCBIXML
# Out:
# 103308

# %% [markdown]
# # 2. Load transcriptome

# %%
## Define the genome reference path
# mouse GRCm38 genome
reference_folder = r'\\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\mouse\GRCm38_ensembl'
transcriptome_folder = r'\\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\mouse\GRCm38_ensembl\Transcriptome'
# Library directories
pool_folder = r'L:\Shiwei\DNA_MERFISH_analysis\SMARTer_nuclei_MOp'

cdna_fasta_file = os.path.join(transcriptome_folder,'Mus_musculus.GRCm38.cdna.all.fa')
ncrna_fasta_file = os.path.join(transcriptome_folder,'Mus_musculus.GRCm38.ncrna.fa')

# %%
def load_transcriptome_fasta_into_dataframe(fasta_file):
    d = {'transcript_id':[], 'seq_type':[], 'location':[], 'gene_id':[],
        'gene_biotype':[], 'transcript_biotype':[], 'gene_symbol':[],
        'description':[], 'seq_length':[], 'sequence':[]}
    
    try:
        for record in SeqIO.parse(fasta_file, 'fasta'):
            split_rd = record.description.split()            
            d['transcript_id'].append(split_rd[0].split('.')[0])
            d['seq_type'].append(split_rd[1])
            d['location'].append(split_rd[2])
            d['gene_id'].append(split_rd[3][5:].split('.')[0])
            d['gene_biotype'].append(split_rd[4][13:])
            d['transcript_biotype'].append(split_rd[5][19:])
            if len(split_rd) > 6:
                d['gene_symbol'].append(split_rd[6][12:])
            else:
                d['gene_symbol'].append(pd.NA)
            if len(split_rd) > 7:
                d['description'].append(' '.join(split_rd[7:])[12:])
            else:
                d['description'].append(pd.NA)
            
            d['seq_length'].append(len(str(record.seq)))
            d['sequence'].append(str(record.seq))
    
    except:
        print(split_rd)
        raise
    
    df = pd.DataFrame.from_dict(d)
    df = df.set_index('transcript_id')
    return df

# %%
# Load the transcriptome fasta
transcriptome_cdna = load_transcriptome_fasta_into_dataframe(cdna_fasta_file)
transcriptome_ncrna = load_transcriptome_fasta_into_dataframe(ncrna_fasta_file)
transcriptome = pd.concat((transcriptome_cdna, transcriptome_ncrna), axis=0)

# %%
print(len(transcriptome))
transcriptome.head()
# Out:
# 141450
#                    seq_type                                  location  \
# transcript_id
# ENSMUST00000177564     cdna  chromosome:GRCm38:14:54122226:54122241:1
# ENSMUST00000196221     cdna  chromosome:GRCm38:14:54113468:54113476:1
# ENSMUST00000179664     cdna  chromosome:GRCm38:14:54113468:54113478:1
# ENSMUST00000178537     cdna   chromosome:GRCm38:6:41533201:41533212:1
# ENSMUST00000178862     cdna   chromosome:GRCm38:6:41542163:41542176:1
#
#                                gene_id gene_biotype    transcript_biotype  \
# transcript_id
# ENSMUST00000177564  ENSMUSG00000096176    TR_D_gene             TR_D_gene
# ENSMUST00000196221  ENSMUSG00000096749    TR_D_gene             TR_D_gene
# ENSMUST00000179664  ENSMUSG00000096749    TR_D_gene  processed_transcript
# ENSMUST00000178537  ENSMUSG00000095668    TR_D_gene             TR_D_gene
# ENSMUST00000178862  ENSMUSG00000094569    TR_D_gene             TR_D_gene
#
#                    gene_symbol  \
# transcript_id
# ENSMUST00000177564       Trdd2
# ENSMUST00000196221       Trdd1
# ENSMUST00000179664       Trdd1
# ENSMUST00000178537       Trbd1
# ENSMUST00000178862       Trbd2
#
#                                                           description  \
# transcript_id
# ENSMUST00000177564  T cell receptor delta diversity 2 [Source:MGI ...
# ENSMUST00000196221  T cell receptor delta diversity 1 [Source:MGI ...
# ENSMUST00000179664  T cell receptor delta diversity 1 [Source:MGI ...
# ENSMUST00000178537  T cell receptor beta, D region 1 [Source:MGI S...
# ENSMUST00000178862  T cell receptor beta, D region 2 [Source:MGI S...
#
#                     seq_length          sequence
# transcript_id
# ENSMUST00000177564          16  ATCGGAGGGATACGAG
# ENSMUST00000196221           9         ATGGCATAT
# ENSMUST00000179664          11       ATGGCATATCA
# ENSMUST00000178537          12      GGGACAGGGGGC
# ENSMUST00000178862          14    GGGACTGGGGGGGC

# %% [markdown]
# # 3. Process MOp genes (genes obtained from smart_seq)

# %%
import scanpy as sc
scRNA_folder =r'L:\Shiwei\DNA_MERFISH_analysis\SMARTer_nuclei_MOp'
# load from here for saved h5ad
adata = sc.read(os.path.join(scRNA_folder,r'MOp_smart_sn_raw.h5ad'))

Mop_genes = adata.var.index.tolist()
len(Mop_genes)
# Out:
# 33262

# %%
# load gene from other notebook
# retrieve genes from the MOp_smart_sn_labeled.h5ad 

#%store -r Mop_genes

# %%
len(Mop_genes)
# Out:
# 33262

# %%
_strands = [1,1,1,1,-1]
import statistics
from statistics import mode
mode(_strands)
# Out:
# 1

# %%
from tqdm.notebook import tqdm

# %%
import statistics
from statistics import mode


# find corresponding gene info from the reference dict
Mop_gene_dict ={}
Mop_gene_dict['gene']=[]
Mop_gene_dict['chr']=[]
Mop_gene_dict['start']=[]
Mop_gene_dict['end']=[]
Mop_gene_dict['gene_biotype']=[]
Mop_gene_dict['coding_strand']=[]

ref_genes = np.unique(transcriptome['gene_symbol'].tolist())


not_found=0
for _gene in tqdm(Mop_genes[:]):
    Mop_gene_dict['gene'].append(_gene)
    
    if _gene in ref_genes:
        _gene_ref_df = transcriptome[transcriptome['gene_symbol']==_gene]
        _location_list = _gene_ref_df['location'].tolist()
        # check format
        if 'chromosome:GRCm38:' == _location_list[0][:18]:
            _start_list = [int(_loc.split('chromosome:GRCm38:')[-1].split(':')[1]) for _loc in _location_list]
            _end_list = [int(_loc.split('chromosome:GRCm38:')[-1].split(':')[2]) for _loc in _location_list]
            Mop_gene_dict['start'].append(np.min(_start_list))
            Mop_gene_dict['end'].append(np.max(_end_list))
            Mop_gene_dict['chr'].append(_location_list[0].split('chromosome:GRCm38:')[-1].split(':')[0])
            # add transcript strand info; use most commen strand
            _strands = [int(_loc.split(':')[-1]) for _loc in _location_list]
            Mop_gene_dict['coding_strand'].append(mode(_strands))
            
        else:
            print (f'Wrong format for {_gene}. Check the result.')
            Mop_gene_dict['start'].append(pd.NA)
            Mop_gene_dict['end'].append(pd.NA)
            Mop_gene_dict['chr'].append(pd.NA)
            Mop_gene_dict['coding_strand'].append(pd.NA)
            
            
        _biotype_list = np.unique(_gene_ref_df['gene_biotype'].tolist())
        if len(_biotype_list)==1:
            Mop_gene_dict['gene_biotype'].append(_biotype_list[0])
        else:
            print(f'Multiple gene biotype exists for {_gene}. Merge the result.')
            merged_biotype = ';'.join(_biotype_list)
            Mop_gene_dict['gene_biotype'].append(merged_biotype)
            
    else:
        print(f'The gene {_gene} not found in the database. Append empty values.')
        Mop_gene_dict['start'].append(pd.NA)
        Mop_gene_dict['end'].append(pd.NA)
        Mop_gene_dict['chr'].append(pd.NA)
        Mop_gene_dict['gene_biotype'].append(pd.NA)
        Mop_gene_dict['coding_strand'].append(pd.NA)
        
        not_found+=1

print (f'There are {not_found} genes not found and were skipped from this query.')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=33262.0), HTML(value='')))
# The gene 0610007P14Rik not found in the database. Append empty values.
# The gene 0610009O20Rik not found in the database. Append empty values.
# The gene 0610010B08Rik not found in the database. Append empty values.
# The gene 0610011F06Rik not found in the database. Append empty values.
# The gene 0610037L13Rik not found in the database. Append empty values.
# The gene 0610039H22Rik not found in the database. Append empty values.
# The gene 1010001N08Rik not found in the database. Append empty values.
# The gene 1110001J03Rik not found in the database. Append empty values.
# The gene 1110004E09Rik not found in the database. Append empty values.
# The gene 1110007C09Rik not found in the database. Append empty values.
# The gene 1110008F13Rik not found in the database. Append empty values.
# The gene 1110008L16Rik not found in the database. Append empty values.
# The gene 1110034G24Rik not found in the database. Append empty values.
# The gene 1110037F02Rik not found in the database. Append empty values.
# The gene 1110054M08Rik not found in the database. Append empty values.
# The gene 1110057K04Rik not found in the database. Append empty values.
# The gene 1110058D11Rik not found in the database. Append empty values.
# The gene 1110058L19Rik not found in the database. Append empty values.
# The gene 1190002F15Rik not found in the database. Append empty values.
# The gene 1190002N15Rik not found in the database. Append empty values.
# The gene 1190003K10Rik not found in the database. Append empty values.
# The gene 1200014J11Rik not found in the database. Append empty values.
# The gene 1500011K16Rik not found in the database. Append empty values.
# The gene 1500012F01Rik not found in the database. Append empty values.
# The gene 1500015O10Rik not found in the database. Append empty values.
# The gene 1500017E21Rik not found in the database. Append empty values.
# The gene 1600002H07Rik not found in the database. Append empty values.
# The gene 1600002K03Rik not found in the database. Append empty values.
# The gene 1600023N17Rik not found in the database. Append empty values.
# The gene 1700001G17Rik not found in the database. Append empty values.
# The gene 1700003M02Rik not found in the database. Append empty values.
# The gene 1700006E09Rik not found in the database. Append empty values.
# The gene 1700006H20Rik not found in the database. Append empty values.
# The gene 1700007B14Rik not found in the database. Append empty values.
# The gene 1700007G11Rik not found in the database. Append empty values.
# The gene 1700007K09Rik not found in the database. Append empty values.
# The gene 1700008F21Rik not found in the database. Append empty values.
# The gene 1700008I05Rik not found in the database. Append empty values.
# The gene 1700011A15Rik not found in the database. Append empty values.
# The gene 1700011E24Rik not found in the database. Append empty values.
# The gene 1700011H14Rik not found in the database. Append empty values.
# The gene 1700011I03Rik not found in the database. Append empty values.
# The gene 1700012D01Rik not found in the database. Append empty values.
# The gene 1700012L04Rik not found in the database. Append empty values.
# The gene 1700015E13Rik not found in the database. Append empty values.
# The gene 1700016C19Rik not found in the database. Append empty values.
# The gene 1700016G14Rik not found in the database. Append empty values.
# The gene 1700016L04Rik not found in the database. Append empty values.
# The gene 1700017D01Rik not found in the database. Append empty values.
# The gene 1700019B03Rik not found in the database. Append empty values.
# The gene 1700019G17Rik not found in the database. Append empty values.
# The gene 1700019L03Rik not found in the database. Append empty values.
# The gene 1700019L22Rik not found in the database. Append empty values.
# The gene 1700020I14Rik not found in the database. Append empty values.
# The gene 1700021F05Rik not found in the database. Append empty values.
# The gene 1700021K19Rik not found in the database. Append empty values.
# The gene 1700023E05Rik not found in the database. Append empty values.
# The gene 1700023F06Rik not found in the database. Append empty values.
# The gene 1700023L04Rik not found in the database. Append empty values.
# The gene 1700024F13Rik not found in the database. Append empty values.
# The gene 1700024P16Rik not found in the database. Append empty values.
# The gene 1700026D08Rik not found in the database. Append empty values.
# The gene 1700026L06Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 1700030C10Rik. Merge the result.
# The gene 1700030F18Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 1700034H15Rik. Merge the result.
# The gene 1700039E15Rik not found in the database. Append empty values.
# The gene 1700040L02Rik not found in the database. Append empty values.
# The gene 1700047I17Rik2 not found in the database. Append empty values.
# The gene 1700049G17Rik not found in the database. Append empty values.
# The gene 1700049J03Rik not found in the database. Append empty values.
# The gene 1700052N19Rik not found in the database. Append empty values.
# The gene 1700054O19Rik not found in the database. Append empty values.
# The gene 1700055N04Rik not found in the database. Append empty values.
# The gene 1700058M13Rik not found in the database. Append empty values.
# The gene 1700061G19Rik not found in the database. Append empty values.
# The gene 1700064F23Rik not found in the database. Append empty values.
# The gene 1700072I22Rik not found in the database. Append empty values.
# The gene 1700080G11Rik not found in the database. Append empty values.
# The gene 1700080G18Rik not found in the database. Append empty values.
# The gene 1700084C01Rik not found in the database. Append empty values.
# The gene 1700101E01Rik not found in the database. Append empty values.
# The gene 1700101G07Rik not found in the database. Append empty values.
# The gene 1700112E06Rik not found in the database. Append empty values.
# The gene 1700112H04Rik not found in the database. Append empty values.
# The gene 1700112N08Rik not found in the database. Append empty values.
# The gene 1700123I01Rik not found in the database. Append empty values.
# The gene 1810010D01Rik not found in the database. Append empty values.
# The gene 1810011H11Rik not found in the database. Append empty values.
# The gene 1810011O10Rik not found in the database. Append empty values.
# The gene 1810013A23Rik not found in the database. Append empty values.
# The gene 1810022K09Rik not found in the database. Append empty values.
# The gene 1810026J23Rik not found in the database. Append empty values.
# The gene 1810032O08Rik not found in the database. Append empty values.
# The gene 1810041L15Rik not found in the database. Append empty values.
# The gene 1810043G02Rik not found in the database. Append empty values.
# The gene 1810043H04Rik not found in the database. Append empty values.
# The gene 2010001E11Rik not found in the database. Append empty values.
# The gene 2010002M12Rik not found in the database. Append empty values.
# The gene 2010005H15Rik not found in the database. Append empty values.
# The gene 2010012O05Rik not found in the database. Append empty values.
# The gene 2010107E04Rik not found in the database. Append empty values.
# The gene 2010107G12Rik not found in the database. Append empty values.
# The gene 2010107G23Rik not found in the database. Append empty values.
# The gene 2010109I03Rik not found in the database. Append empty values.
# The gene 2010111I01Rik not found in the database. Append empty values.
# The gene 2010300F17Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 2010320M18Rik. Merge the result.
# The gene 2210008F06Rik not found in the database. Append empty values.
# The gene 2210011C24Rik not found in the database. Append empty values.
# The gene 2210013O21Rik not found in the database. Append empty values.
# The gene 2210015D19Rik not found in the database. Append empty values.
# The gene 2210018M11Rik not found in the database. Append empty values.
# The gene 2210404O09Rik not found in the database. Append empty values.
# The gene 2210416O15Rik not found in the database. Append empty values.
# The gene 2300005B03Rik not found in the database. Append empty values.
# The gene 2310003H01Rik not found in the database. Append empty values.
# The gene 2310009A05Rik not found in the database. Append empty values.
# The gene 2310014L17Rik not found in the database. Append empty values.
# The gene 2310034P14Rik not found in the database. Append empty values.
# The gene 2310035C23Rik not found in the database. Append empty values.
# The gene 2310036O22Rik not found in the database. Append empty values.
# The gene 2310045N01Rik not found in the database. Append empty values.
# The gene 2310047M10Rik not found in the database. Append empty values.
# The gene 2310061J03Rik not found in the database. Append empty values.
# The gene 2310067B10Rik not found in the database. Append empty values.
# The gene 2310067E19Rik not found in the database. Append empty values.
# The gene 2310069G16Rik not found in the database. Append empty values.
# The gene 2310075K07Rik not found in the database. Append empty values.
# The gene 2410004N09Rik not found in the database. Append empty values.
# The gene 2410007B07Rik not found in the database. Append empty values.
# The gene 2410015M20Rik not found in the database. Append empty values.
# The gene 2410016O06Rik not found in the database. Append empty values.
# The gene 2410089E03Rik not found in the database. Append empty values.
# The gene 2410114N07Rik not found in the database. Append empty values.
# The gene 2410127L17Rik not found in the database. Append empty values.
# The gene 2510003B16Rik not found in the database. Append empty values.
# The gene 2510003E04Rik not found in the database. Append empty values.
# The gene 2610002J02Rik not found in the database. Append empty values.
# The gene 2610015P09Rik not found in the database. Append empty values.
# The gene 2610020H08Rik not found in the database. Append empty values.
# The gene 2610034B18Rik not found in the database. Append empty values.
# The gene 2610100L16Rik not found in the database. Append empty values.
# The gene 2610203C20Rik not found in the database. Append empty values.
# The gene 2610305D13Rik not found in the database. Append empty values.
# The gene 2610524H06Rik not found in the database. Append empty values.
# The gene 2700012I20Rik not found in the database. Append empty values.
# The gene 2700029M09Rik not found in the database. Append empty values.
# The gene 2700060E02Rik not found in the database. Append empty values.
# The gene 2700070H01Rik not found in the database. Append empty values.
# The gene 2700089E24Rik not found in the database. Append empty values.
# The gene 2700094K13Rik not found in the database. Append empty values.
# The gene 2810008D09Rik not found in the database. Append empty values.
# The gene 2810403A07Rik not found in the database. Append empty values.
# The gene 2810405F15Rik not found in the database. Append empty values.
# The gene 2810408B13Rik not found in the database. Append empty values.
# The gene 2810408M09Rik not found in the database. Append empty values.
# The gene 2810416G20Rik not found in the database. Append empty values.
# The gene 2810417H13Rik not found in the database. Append empty values.
# The gene 2810428I15Rik not found in the database. Append empty values.
# The gene 2810468N07Rik not found in the database. Append empty values.
# The gene 2810474O19Rik not found in the database. Append empty values.
# The gene 2900008C10Rik not found in the database. Append empty values.
# The gene 2900011O08Rik not found in the database. Append empty values.
# The gene 2900055J20Rik not found in the database. Append empty values.
# The gene 2900092D14Rik not found in the database. Append empty values.
# The gene 3010026O09Rik not found in the database. Append empty values.
# The gene 3110002H16Rik not found in the database. Append empty values.
# The gene 3110007F17Rik not found in the database. Append empty values.
# The gene 3110035E14Rik not found in the database. Append empty values.
# The gene 3110039I08Rik not found in the database. Append empty values.
# The gene 3110043O21Rik not found in the database. Append empty values.
# The gene 3110052M02Rik not found in the database. Append empty values.
# The gene 3110057O12Rik not found in the database. Append empty values.
# The gene 3110062M04Rik not found in the database. Append empty values.
# The gene 3110079O15Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 3300002P13Rik. Merge the result.
# The gene 3632451O06Rik not found in the database. Append empty values.
# The gene 4631405K08Rik not found in the database. Append empty values.
# The gene 4632428N05Rik not found in the database. Append empty values.
# The gene 4732416N19Rik not found in the database. Append empty values.
# The gene 4831407H17Rik not found in the database. Append empty values.
# The gene 4831440E17Rik not found in the database. Append empty values.
# The gene 4833403I15Rik not found in the database. Append empty values.
# The gene 4833447I15Rik not found in the database. Append empty values.
# The gene 4833447P13Rik not found in the database. Append empty values.
# The gene 4921501E09Rik not found in the database. Append empty values.
# The gene 4921506M07Rik not found in the database. Append empty values.
# The gene 4921507L20Rik not found in the database. Append empty values.
# The gene 4921511H03Rik not found in the database. Append empty values.
# The gene 4921513H07Rik not found in the database. Append empty values.
# The gene 4930407I02Rik not found in the database. Append empty values.
# The gene 4930413G21Rik not found in the database. Append empty values.
# The gene 4930414L22Rik not found in the database. Append empty values.
# The gene 4930415F15Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 4930417H01Rik. Merge the result.
# The gene 4930421P05Rik not found in the database. Append empty values.
# The gene 4930427A07Rik not found in the database. Append empty values.
# The gene 4930428G15Rik not found in the database. Append empty values.
# The gene 4930429B21Rik not found in the database. Append empty values.
# The gene 4930430A15Rik not found in the database. Append empty values.
# The gene 4930430J02Rik not found in the database. Append empty values.
# The gene 4930442E04Rik not found in the database. Append empty values.
# The gene 4930444M15Rik not found in the database. Append empty values.
# The gene 4930455D15Rik not found in the database. Append empty values.
# The gene 4930455F16Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 4930455G09Rik. Merge the result.
# The gene 4930469G21Rik not found in the database. Append empty values.
# The gene 4930474G06Rik not found in the database. Append empty values.
# The gene 4930480K23Rik not found in the database. Append empty values.
# The gene 4930482G09Rik not found in the database. Append empty values.
# The gene 4930487H11Rik not found in the database. Append empty values.
# The gene 4930500G05Rik not found in the database. Append empty values.
# The gene 4930500J02Rik not found in the database. Append empty values.
# The gene 4930502C15Rik not found in the database. Append empty values.
# The gene 4930502E18Rik not found in the database. Append empty values.
# The gene 4930502M04Rik not found in the database. Append empty values.
# The gene 4930506A18Rik not found in the database. Append empty values.
# The gene 4930506M07Rik not found in the database. Append empty values.
# The gene 4930511A08Rik not found in the database. Append empty values.
# The gene 4930515L03Rik not found in the database. Append empty values.
# The gene 4930517G24Rik not found in the database. Append empty values.
# The gene 4930518F22Rik not found in the database. Append empty values.
# The gene 4930521O11Rik not found in the database. Append empty values.
# The gene 4930522P08Rik not found in the database. Append empty values.
# The gene 4930525D18Rik not found in the database. Append empty values.
# The gene 4930526I15Rik not found in the database. Append empty values.
# The gene 4930528A17Rik not found in the database. Append empty values.
# The gene 4930538K18Rik not found in the database. Append empty values.
# The gene 4930539E08Rik not found in the database. Append empty values.
# The gene 4930539N22Rik not found in the database. Append empty values.
# The gene 4930542C21Rik not found in the database. Append empty values.
# The gene 4930542N06Rik not found in the database. Append empty values.
# The gene 4930543D07Rik not found in the database. Append empty values.
# The gene 4930552P12Rik not found in the database. Append empty values.
# The gene 4930553C11Rik not found in the database. Append empty values.
# The gene 4930557B15Rik not found in the database. Append empty values.
# The gene 4930563D23Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 4930563F08Rik. Merge the result.
# The gene 4930570G05Rik not found in the database. Append empty values.
# The gene 4930572J10Rik not found in the database. Append empty values.
# The gene 4930573O16Rik not found in the database. Append empty values.
# The gene 4930577N17Rik not found in the database. Append empty values.
# The gene 4930578C19Rik not found in the database. Append empty values.
# The gene 4930594C11Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 4930594M22Rik. Merge the result.
# The gene 4931402G19Rik not found in the database. Append empty values.
# The gene 4931403G20Rik not found in the database. Append empty values.
# The gene 4931403M11Rik not found in the database. Append empty values.
# The gene 4931408D14Rik not found in the database. Append empty values.
# The gene 4931409K22Rik not found in the database. Append empty values.
# The gene 4931412M21 not found in the database. Append empty values.
# The gene 4931423N10Rik not found in the database. Append empty values.
# The gene 4931429I11Rik not found in the database. Append empty values.
# The gene 4931430N09Rik not found in the database. Append empty values.
# The gene 4931440F15Rik not found in the database. Append empty values.
# The gene 4931440J10Rik not found in the database. Append empty values.
# The gene 4932411E22Rik not found in the database. Append empty values.
# The gene 4932416H05Rik not found in the database. Append empty values.
# The gene 4932418E24Rik not found in the database. Append empty values.
# The gene 4932442L08Rik not found in the database. Append empty values.
# The gene 4932443I19Rik not found in the database. Append empty values.
# The gene 4933406M09Rik not found in the database. Append empty values.
# The gene 4933407G14Rik not found in the database. Append empty values.
# The gene 4933408B17Rik not found in the database. Append empty values.
# The gene 4933411G11Rik not found in the database. Append empty values.
# The gene 4933413G19Rik not found in the database. Append empty values.
# The gene 4933416C03Rik not found in the database. Append empty values.
# The gene 4933416M06Rik not found in the database. Append empty values.
# The gene 4933425L06Rik not found in the database. Append empty values.
# The gene 4933427G17Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 4933432I09Rik. Merge the result.
# The gene 4933433C11Rik not found in the database. Append empty values.
# The gene 5031414D18Rik not found in the database. Append empty values.
# The gene 5031426D15Rik not found in the database. Append empty values.
# The gene 5330426P16Rik not found in the database. Append empty values.
# The gene 5330432E05Rik not found in the database. Append empty values.
# The gene 5430416O09Rik not found in the database. Append empty values.
# The gene 5430419D17Rik not found in the database. Append empty values.
# The gene 5430435G22Rik not found in the database. Append empty values.
# The gene 5730408K05Rik not found in the database. Append empty values.
# The gene 5730409K12Rik not found in the database. Append empty values.
# The gene 5730422E09Rik not found in the database. Append empty values.
# The gene 5730508B09Rik not found in the database. Append empty values.
# The gene 5730559C18Rik not found in the database. Append empty values.
# The gene 5830403F22Rik not found in the database. Append empty values.
# The gene 5830415F09Rik not found in the database. Append empty values.
# The gene 5830416P10Rik not found in the database. Append empty values.
# The gene 5830428H23Rik not found in the database. Append empty values.
# The gene 5830433I10Rik not found in the database. Append empty values.
# The gene 5830473C10Rik not found in the database. Append empty values.
# The gene 5930403L14Rik not found in the database. Append empty values.
# The gene 5930412G12Rik not found in the database. Append empty values.
# The gene 6030408B16Rik not found in the database. Append empty values.
# The gene 6030419C18Rik not found in the database. Append empty values.
# The gene 6030426L16Rik not found in the database. Append empty values.
# The gene 6330403A02Rik not found in the database. Append empty values.
# The gene 6330407A03Rik not found in the database. Append empty values.
# The gene 6330408A02Rik not found in the database. Append empty values.
# The gene 6330415B21Rik not found in the database. Append empty values.
# The gene 6330416G13Rik not found in the database. Append empty values.
# The gene 6330419J24Rik not found in the database. Append empty values.
# The gene 6430531B16Rik not found in the database. Append empty values.
# The gene 6430573F11Rik not found in the database. Append empty values.
# Multiple gene biotype exists for 6430590A07Rik. Merge the result.
# The gene 6430590A10Rik not found in the database. Append empty values.
# The gene 6720432D03Rik not found in the database. Append empty values.
# The gene 8430408G22Rik not found in the database. Append empty values.
# The gene 8430415O14Rik not found in the database. Append empty values.
# The gene 8430419L09Rik not found in the database. Append empty values.
# The gene 8430431K14Rik not found in the database. Append empty values.
# The gene 9030617O03Rik not found in the database. Append empty values.
# The gene 9030624J02Rik not found in the database. Append empty values.
# The gene 9130011E15Rik not found in the database. Append empty values.
# The gene 9230104L09Rik not found in the database. Append empty values.
# The gene 9230110C19Rik not found in the database. Append empty values.
# The gene 9230110F15Rik not found in the database. Append empty values.
# The gene 9230113P08Rik not found in the database. Append empty values.
# The gene 9330133O14Rik not found in the database. Append empty values.
# The gene 9330155M09Rik not found in the database. Append empty values.
# The gene 9430008C03Rik not found in the database. Append empty values.
# The gene 9430016H08Rik not found in the database. Append empty values.
# The gene 9430020K01Rik not found in the database. Append empty values.
# The gene 9430076C15Rik not found in the database. Append empty values.
# The gene 9430078G10Rik not found in the database. Append empty values.
# The gene 9430083A17Rik not found in the database. Append empty values.
# The gene 9530027J09Rik not found in the database. Append empty values.
# The gene 9530047P18Rik not found in the database. Append empty values.
# The gene 9530053H05Rik not found in the database. Append empty values.
# The gene 9530057J20Rik not found in the database. Append empty values.
# The gene 9530091C08Rik not found in the database. Append empty values.
# The gene 9630033F20Rik not found in the database. Append empty values.
# The gene 9830147E19Rik not found in the database. Append empty values.
# The gene A230046K03Rik not found in the database. Append empty values.
# The gene A230050P20Rik not found in the database. Append empty values.
# The gene A230056J06Rik not found in the database. Append empty values.
# The gene A230065H16Rik not found in the database. Append empty values.
# The gene A230070E04Rik not found in the database. Append empty values.
# The gene A230073K19Rik not found in the database. Append empty values.
# The gene A330050F15Rik not found in the database. Append empty values.
# The gene A330069E16Rik not found in the database. Append empty values.
# The gene A430046D13Rik not found in the database. Append empty values.
# The gene A430078G23Rik not found in the database. Append empty values.
# The gene A430085M09Rik not found in the database. Append empty values.
# The gene A430105I19Rik not found in the database. Append empty values.
# The gene A530050N04Rik not found in the database. Append empty values.
# The gene A530054K11Rik not found in the database. Append empty values.
# The gene A630020A06 not found in the database. Append empty values.
# The gene A630033H20Rik not found in the database. Append empty values.
# The gene A630034I12Rik not found in the database. Append empty values.
# The gene A630066F11Rik not found in the database. Append empty values.
# The gene A630075F10Rik not found in the database. Append empty values.
# The gene A630077J23Rik not found in the database. Append empty values.
# The gene A630081J09Rik not found in the database. Append empty values.
# Multiple gene biotype exists for A730006G06Rik. Merge the result.
# The gene A730013G03Rik not found in the database. Append empty values.
# The gene A730017C20Rik not found in the database. Append empty values.
# The gene A730067D02Rik not found in the database. Append empty values.
# The gene A730089K16Rik not found in the database. Append empty values.
# The gene A730090H04Rik not found in the database. Append empty values.
# The gene A730098P11Rik not found in the database. Append empty values.
# The gene A830010M20Rik not found in the database. Append empty values.
# The gene A830021M18Rik not found in the database. Append empty values.
# The gene A830080D01Rik not found in the database. Append empty values.
# The gene A930011G23Rik not found in the database. Append empty values.
# The gene A930011O12Rik not found in the database. Append empty values.
# The gene A930013F10Rik not found in the database. Append empty values.
# The gene A930018M24Rik not found in the database. Append empty values.
# The gene AA414992 not found in the database. Append empty values.
# The gene AA415398 not found in the database. Append empty values.
# The gene AA474331 not found in the database. Append empty values.
# The gene AA543186 not found in the database. Append empty values.
# The gene AA987161 not found in the database. Append empty values.
# The gene AF251705 not found in the database. Append empty values.
# The gene AF357355 not found in the database. Append empty values.
# The gene AF357359 not found in the database. Append empty values.
# The gene AF357426 not found in the database. Append empty values.
# The gene AF529169 not found in the database. Append empty values.
# The gene AI118078 not found in the database. Append empty values.
# The gene AI314180 not found in the database. Append empty values.
# The gene AI317395 not found in the database. Append empty values.
# The gene AI450353 not found in the database. Append empty values.
# The gene AI464131 not found in the database. Append empty values.
# The gene AI481877 not found in the database. Append empty values.
# The gene AI846148 not found in the database. Append empty values.
# The gene AI854517 not found in the database. Append empty values.
# The gene AK010878 not found in the database. Append empty values.
# The gene AK129341 not found in the database. Append empty values.
# The gene ATP6 not found in the database. Append empty values.
# The gene ATP8 not found in the database. Append empty values.
# The gene AU019823 not found in the database. Append empty values.
# The gene AU040096 not found in the database. Append empty values.
# The gene AV051173 not found in the database. Append empty values.
# The gene AW121686 not found in the database. Append empty values.
# The gene AW549542 not found in the database. Append empty values.
# The gene Aaed1 not found in the database. Append empty values.
# The gene Acn9 not found in the database. Append empty values.
# The gene Acpt not found in the database. Append empty values.
# The gene Adck3 not found in the database. Append empty values.
# The gene Adck4 not found in the database. Append empty values.
# The gene Adrbk1 not found in the database. Append empty values.
# The gene Adrbk2 not found in the database. Append empty values.
# The gene Aes not found in the database. Append empty values.
# The gene Agpat6 not found in the database. Append empty values.
# The gene Agpat9 not found in the database. Append empty values.
# The gene Aim1 not found in the database. Append empty values.
# The gene Aim1l not found in the database. Append empty values.
# The gene Akap2 not found in the database. Append empty values.
# The gene Als2cr11 not found in the database. Append empty values.
# The gene Als2cr12 not found in the database. Append empty values.
# The gene Amica1 not found in the database. Append empty values.
# The gene Ankrd32 not found in the database. Append empty values.
# Multiple gene biotype exists for Anxa13. Merge the result.
# The gene Apitd1 not found in the database. Append empty values.
# The gene Apoa1bp not found in the database. Append empty values.
# The gene Art2a-ps not found in the database. Append empty values.
# The gene Asun not found in the database. Append empty values.
# The gene Athl1 not found in the database. Append empty values.
# The gene Atp5f1 not found in the database. Append empty values.
# The gene Atp5k-ps1 not found in the database. Append empty values.
# The gene Atp5k-ps3 not found in the database. Append empty values.
# The gene Atp5s not found in the database. Append empty values.
# The gene Atp5sl not found in the database. Append empty values.
# The gene B020018G12Rik not found in the database. Append empty values.
# The gene B130006D01Rik not found in the database. Append empty values.
# The gene B130016D09Rik not found in the database. Append empty values.
# The gene B230118I11Rik not found in the database. Append empty values.
# The gene B230216G23Rik not found in the database. Append empty values.
# The gene B230344G16Rik not found in the database. Append empty values.
# Multiple gene biotype exists for B230369F24Rik. Merge the result.
# The gene B430319G15Rik not found in the database. Append empty values.
# The gene B630005N14Rik not found in the database. Append empty values.
# The gene B930003M22Rik not found in the database. Append empty values.
# The gene B930041F14Rik not found in the database. Append empty values.
# The gene B930082K07Rik not found in the database. Append empty values.
# The gene BB094273 not found in the database. Append empty values.
# The gene BB114814 not found in the database. Append empty values.
# The gene BB283400 not found in the database. Append empty values.
# The gene BC002163 not found in the database. Append empty values.
# The gene BC003331 not found in the database. Append empty values.
# The gene BC005512 not found in the database. Append empty values.
# The gene BC005561 not found in the database. Append empty values.
# The gene BC017643 not found in the database. Append empty values.
# The gene BC020402 not found in the database. Append empty values.
# The gene BC021785 not found in the database. Append empty values.
# The gene BC021891 not found in the database. Append empty values.
# The gene BC022687 not found in the database. Append empty values.
# The gene BC023829 not found in the database. Append empty values.
# The gene BC025446 not found in the database. Append empty values.
# The gene BC026585 not found in the database. Append empty values.
# The gene BC027072 not found in the database. Append empty values.
# The gene BC027231 not found in the database. Append empty values.
# The gene BC029214 not found in the database. Append empty values.
# The gene BC030307 not found in the database. Append empty values.
# The gene BC030336 not found in the database. Append empty values.
# The gene BC030499 not found in the database. Append empty values.
# The gene BC030867 not found in the database. Append empty values.
# The gene BC030870 not found in the database. Append empty values.
# The gene BC031361 not found in the database. Append empty values.
# The gene BC033916 not found in the database. Append empty values.
# The gene BC037034 not found in the database. Append empty values.
# The gene BC039771 not found in the database. Append empty values.
# The gene BC048502 not found in the database. Append empty values.
# The gene BC048546 not found in the database. Append empty values.
# The gene BC048609 not found in the database. Append empty values.
# The gene BC049635 not found in the database. Append empty values.
# The gene BC049702 not found in the database. Append empty values.
# The gene BC052688 not found in the database. Append empty values.
# The gene BC055111 not found in the database. Append empty values.
# The gene BC061194 not found in the database. Append empty values.
# The gene BC068281 not found in the database. Append empty values.
# The gene BC089491 not found in the database. Append empty values.
# The gene BC100451 not found in the database. Append empty values.
# The gene BE949265 not found in the database. Append empty values.
# The gene Bai1 not found in the database. Append empty values.
# The gene Bai2 not found in the database. Append empty values.
# The gene Bai3 not found in the database. Append empty values.
# The gene Bmp4-ps not found in the database. Append empty values.
# The gene Bre not found in the database. Append empty values.
# The gene Btg1-ps2 not found in the database. Append empty values.
# The gene Bzrap1 not found in the database. Append empty values.
# The gene C030016D13Rik not found in the database. Append empty values.
# The gene C030023E24Rik not found in the database. Append empty values.
# The gene C030039L03Rik not found in the database. Append empty values.
# The gene C130023O10Rik not found in the database. Append empty values.
# The gene C130030K03Rik not found in the database. Append empty values.
# The gene C130060K24Rik not found in the database. Append empty values.
# The gene C230004F18Rik not found in the database. Append empty values.
# The gene C230029M16 not found in the database. Append empty values.
# The gene C230052I12Rik not found in the database. Append empty values.
# The gene C230091D08Rik not found in the database. Append empty values.
# The gene C330006A16Rik not found in the database. Append empty values.
# The gene C330013J21Rik not found in the database. Append empty values.
# The gene C330016L05Rik not found in the database. Append empty values.
# The gene C330020E22Rik not found in the database. Append empty values.
# The gene C330021F23Rik not found in the database. Append empty values.
# The gene C330027C09Rik not found in the database. Append empty values.
# The gene C430049E01Rik not found in the database. Append empty values.
# The gene C77370 not found in the database. Append empty values.
# The gene C78339 not found in the database. Append empty values.
# The gene C920025E04Rik not found in the database. Append empty values.
# The gene COX1 not found in the database. Append empty values.
# The gene COX2 not found in the database. Append empty values.
# The gene COX3 not found in the database. Append empty values.
# The gene CYTB not found in the database. Append empty values.
# The gene Carkd not found in the database. Append empty values.
# The gene Casc5 not found in the database. Append empty values.
# The gene Ccbl1 not found in the database. Append empty values.
# The gene Ccbl2 not found in the database. Append empty values.
# The gene Ccdc101 not found in the database. Append empty values.
# The gene Ccdc108 not found in the database. Append empty values.
# The gene Ccdc109b not found in the database. Append empty values.
# The gene Ccdc129 not found in the database. Append empty values.
# The gene Ccdc132 not found in the database. Append empty values.
# The gene Ccdc168 not found in the database. Append empty values.
# The gene Ccdc176 not found in the database. Append empty values.
# The gene Ccdc23 not found in the database. Append empty values.
# The gene Ccdc37 not found in the database. Append empty values.
# The gene Ccdc42b not found in the database. Append empty values.
# The gene Ccdc53 not found in the database. Append empty values.
# The gene Ccdc55 not found in the database. Append empty values.
# The gene Ccdc64 not found in the database. Append empty values.
# The gene Ccdc64b not found in the database. Append empty values.
# The gene Ccdc7 not found in the database. Append empty values.
# The gene Ccdc79 not found in the database. Append empty values.
# The gene Ccdc94 not found in the database. Append empty values.
# The gene Ccl16-ps not found in the database. Append empty values.
# Wrong format for Ccl19. Check the result.
# Wrong format for Ccl21a. Check the result.
# Wrong format for Ccl27a. Check the result.
# The gene Ccpn-ps not found in the database. Append empty values.
# The gene Ccrn4l not found in the database. Append empty values.
# The gene Cd244 not found in the database. Append empty values.
# The gene Cd97 not found in the database. Append empty values.
# The gene Cdc34-ps not found in the database. Append empty values.
# The gene Cdk3-ps not found in the database. Append empty values.
# The gene Cecr5 not found in the database. Append empty values.
# The gene Cecr6 not found in the database. Append empty values.
# The gene Cep112os2 not found in the database. Append empty values.
# The gene Chd3os not found in the database. Append empty values.
# The gene Cirh1a not found in the database. Append empty values.
# The gene Cistr-act not found in the database. Append empty values.
# The gene Ck-ps1 not found in the database. Append empty values.
# The gene Ck-ps3 not found in the database. Append empty values.
# The gene Clcn4-2 not found in the database. Append empty values.
# The gene Cml1 not found in the database. Append empty values.
# The gene Cml2 not found in the database. Append empty values.
# The gene Cml3 not found in the database. Append empty values.
# The gene Cml5 not found in the database. Append empty values.
# The gene Cox20-ps not found in the database. Append empty values.
# The gene Cpo not found in the database. Append empty values.
# The gene Cpsf3l not found in the database. Append empty values.
# The gene Csrp2bp not found in the database. Append empty values.
# The gene Ctage5 not found in the database. Append empty values.
# The gene Ctgf not found in the database. Append empty values.
# The gene Cxx1a not found in the database. Append empty values.
# The gene Cxx1b not found in the database. Append empty values.
# The gene Cxx1c not found in the database. Append empty values.
# The gene Cycl not found in the database. Append empty values.
# The gene Cycs-ps1 not found in the database. Append empty values.
# The gene Cyp2b28-ps not found in the database. Append empty values.
# The gene Cyp2c44 not found in the database. Append empty values.
# The gene Cyp3a58-ps not found in the database. Append empty values.
# The gene Cyr61 not found in the database. Append empty values.
# The gene D030054H15Rik not found in the database. Append empty values.
# The gene D10Bwg1379e not found in the database. Append empty values.
# The gene D10Jhu81e not found in the database. Append empty values.
# The gene D130037M23Rik not found in the database. Append empty values.
# The gene D130058E03 not found in the database. Append empty values.
# The gene D15Ertd621e not found in the database. Append empty values.
# The gene D16Ertd727e not found in the database. Append empty values.
# The gene D17Ertd648e not found in the database. Append empty values.
# The gene D17H6S56E-5 not found in the database. Append empty values.
# The gene D17Wsu92e not found in the database. Append empty values.
# The gene D19Bwg1357e not found in the database. Append empty values.
# The gene D230017M19Rik not found in the database. Append empty values.
# The gene D2Wsu81e not found in the database. Append empty values.
# The gene D330045A20Rik not found in the database. Append empty values.
# The gene D3Ertd254e not found in the database. Append empty values.
# The gene D4Ertd617e not found in the database. Append empty values.
# The gene D630010B17Rik not found in the database. Append empty values.
# The gene D630013N20Rik not found in the database. Append empty values.
# The gene D630041G03Rik not found in the database. Append empty values.
# The gene D630045M09Rik not found in the database. Append empty values.
# The gene D730005E14Rik not found in the database. Append empty values.
# The gene D830014E11Rik not found in the database. Append empty values.
# The gene D830031N03Rik not found in the database. Append empty values.
# The gene D830044I16Rik not found in the database. Append empty values.
# The gene D830046C22Rik not found in the database. Append empty values.
# The gene D8Ertd82e not found in the database. Append empty values.
# The gene D930015E06Rik not found in the database. Append empty values.
# The gene D930016D06Rik not found in the database. Append empty values.
# The gene D930030F02Rik not found in the database. Append empty values.
# The gene Daf2 not found in the database. Append empty values.
# The gene Dak not found in the database. Append empty values.
# The gene Dbf4b not found in the database. Append empty values.
# The gene Ddx26b not found in the database. Append empty values.
# The gene Dear1 not found in the database. Append empty values.
# The gene Deb1 not found in the database. Append empty values.
# The gene Dfna5 not found in the database. Append empty values.
# The gene Dfnb59 not found in the database. Append empty values.
# The gene Dgcr14 not found in the database. Append empty values.
# The gene Diap1 not found in the database. Append empty values.
# The gene Diap2 not found in the database. Append empty values.
# The gene Diap3 not found in the database. Append empty values.
# The gene Diexf not found in the database. Append empty values.
# The gene Dirc2 not found in the database. Append empty values.
# Multiple gene biotype exists for Dlx6os1. Merge the result.
# The gene Dlx6os2 not found in the database. Append empty values.
# The gene Dnmt3b-ps1 not found in the database. Append empty values.
# The gene Dopey1 not found in the database. Append empty values.
# The gene Dopey2 not found in the database. Append empty values.
# The gene Dos not found in the database. Append empty values.
# The gene Dpcd not found in the database. Append empty values.
# The gene Dpcr1 not found in the database. Append empty values.
# The gene Dscr3 not found in the database. Append empty values.
# The gene Dyx1c1 not found in the database. Append empty values.
# The gene E030003E18Rik not found in the database. Append empty values.
# The gene E030007A22Rik not found in the database. Append empty values.
# The gene E030011O05Rik not found in the database. Append empty values.
# The gene E030019B13Rik not found in the database. Append empty values.
# The gene E030046B03Rik not found in the database. Append empty values.
# The gene E130012A19Rik not found in the database. Append empty values.
# The gene E130112N10Rik not found in the database. Append empty values.
# The gene E130309D14Rik not found in the database. Append empty values.
# The gene E230008N13Rik not found in the database. Append empty values.
# The gene E330009J07Rik not found in the database. Append empty values.
# The gene E330033B04Rik not found in the database. Append empty values.
# The gene E430016F16Rik not found in the database. Append empty values.
# The gene E430025E21Rik not found in the database. Append empty values.
# The gene E530001K10Rik not found in the database. Append empty values.
# The gene Efcab13 not found in the database. Append empty values.
# The gene Eftud1 not found in the database. Append empty values.
# The gene Eltd1 not found in the database. Append empty values.
# The gene Emr1 not found in the database. Append empty values.
# The gene Emr4 not found in the database. Append empty values.
# The gene Enthd2 not found in the database. Append empty values.
# The gene Epb4.1 not found in the database. Append empty values.
# The gene Epb4.1l1 not found in the database. Append empty values.
# The gene Epb4.1l2 not found in the database. Append empty values.
# The gene Epb4.1l3 not found in the database. Append empty values.
# The gene Epb4.1l4a not found in the database. Append empty values.
# The gene Epb4.1l4b not found in the database. Append empty values.
# The gene Epb4.1l5 not found in the database. Append empty values.
# The gene Epb4.2 not found in the database. Append empty values.
# The gene Ept1 not found in the database. Append empty values.
# The gene Erbb2ip not found in the database. Append empty values.
# The gene Etohi1 not found in the database. Append empty values.
# The gene Etv3l not found in the database. Append empty values.
# The gene F420015M19Rik not found in the database. Append empty values.
# The gene F630111L10Rik not found in the database. Append empty values.
# The gene F830002L21Rik not found in the database. Append empty values.
# Multiple gene biotype exists for F830208F22Rik. Merge the result.
# The gene F930015N05Rik not found in the database. Append empty values.
# The gene Faim3 not found in the database. Append empty values.
# The gene Fam101a not found in the database. Append empty values.
# The gene Fam101b not found in the database. Append empty values.
# The gene Fam103a1 not found in the database. Append empty values.
# The gene Fam105a not found in the database. Append empty values.
# The gene Fam109a not found in the database. Append empty values.
# The gene Fam109b not found in the database. Append empty values.
# The gene Fam120aos not found in the database. Append empty values.
# The gene Fam132a not found in the database. Append empty values.
# The gene Fam132b not found in the database. Append empty values.
# The gene Fam134a not found in the database. Append empty values.
# The gene Fam134b not found in the database. Append empty values.
# The gene Fam134c not found in the database. Append empty values.
# The gene Fam150a not found in the database. Append empty values.
# The gene Fam150b not found in the database. Append empty values.
# The gene Fam154a not found in the database. Append empty values.
# The gene Fam154b not found in the database. Append empty values.
# The gene Fam159a not found in the database. Append empty values.
# The gene Fam159b not found in the database. Append empty values.
# The gene Fam173b not found in the database. Append empty values.
# The gene Fam175a not found in the database. Append empty values.
# The gene Fam175b not found in the database. Append empty values.
# The gene Fam178a not found in the database. Append empty values.
# The gene Fam179a not found in the database. Append empty values.
# The gene Fam179b not found in the database. Append empty values.
# The gene Fam188a not found in the database. Append empty values.
# The gene Fam188b not found in the database. Append empty values.
# The gene Fam188b2 not found in the database. Append empty values.
# The gene Fam195a not found in the database. Append empty values.
# The gene Fam195b not found in the database. Append empty values.
# The gene Fam196a not found in the database. Append empty values.
# The gene Fam196b not found in the database. Append empty values.
# The gene Fam198a not found in the database. Append empty values.
# The gene Fam198b not found in the database. Append empty values.
# The gene Fam19a1 not found in the database. Append empty values.
# The gene Fam19a2 not found in the database. Append empty values.
# The gene Fam19a3 not found in the database. Append empty values.
# The gene Fam19a4 not found in the database. Append empty values.
# The gene Fam19a5 not found in the database. Append empty values.
# The gene Fam206a not found in the database. Append empty values.
# The gene Fam208a not found in the database. Append empty values.
# The gene Fam208b not found in the database. Append empty values.
# The gene Fam21 not found in the database. Append empty values.
# The gene Fam212a not found in the database. Append empty values.
# The gene Fam212b not found in the database. Append empty values.
# The gene Fam213a not found in the database. Append empty values.
# ...
# The gene Orai2-ps not found in the database. Append empty values.
# The gene Oraov1 not found in the database. Append empty values.
# The gene Pacrgl not found in the database. Append empty values.
# The gene Palm2 not found in the database. Append empty values.
# The gene Papd4 not found in the database. Append empty values.
# The gene Papd5 not found in the database. Append empty values.
# The gene Papd7 not found in the database. Append empty values.
# The gene Papl not found in the database. Append empty values.
# The gene Park2 not found in the database. Append empty values.
# The gene Pcdha10 not found in the database. Append empty values.
# The gene Pcdha4-g not found in the database. Append empty values.
# The gene Pcdha6-g not found in the database. Append empty values.
# The gene Pcdha7-g not found in the database. Append empty values.
# The gene Pcnxl2 not found in the database. Append empty values.
# The gene Pcnxl3 not found in the database. Append empty values.
# The gene Pcnxl4 not found in the database. Append empty values.
# The gene Pddc1 not found in the database. Append empty values.
# The gene Peo1 not found in the database. Append empty values.
# The gene Pet2 not found in the database. Append empty values.
# The gene Phf5b-ps not found in the database. Append empty values.
# The gene Phxr4 not found in the database. Append empty values.
# The gene Pla2g16 not found in the database. Append empty values.
# The gene Pomc-ps1 not found in the database. Append empty values.
# The gene Ppap2a not found in the database. Append empty values.
# The gene Ppap2b not found in the database. Append empty values.
# The gene Ppap2c not found in the database. Append empty values.
# The gene Ppapdc1a not found in the database. Append empty values.
# The gene Ppapdc1b not found in the database. Append empty values.
# The gene Ppapdc2 not found in the database. Append empty values.
# The gene Ppapdc3 not found in the database. Append empty values.
# The gene Ppp1r2-ps5 not found in the database. Append empty values.
# The gene Ppp1r3fos not found in the database. Append empty values.
# The gene Ppp2r4 not found in the database. Append empty values.
# The gene Pqlc1 not found in the database. Append empty values.
# The gene Prdx2-rs3 not found in the database. Append empty values.
# The gene Prkcdbp not found in the database. Append empty values.
# The gene Prkrir not found in the database. Append empty values.
# The gene Prmt10 not found in the database. Append empty values.
# The gene Prosc not found in the database. Append empty values.
# The gene Prune not found in the database. Append empty values.
# The gene Psmb7-ps1 not found in the database. Append empty values.
# The gene Ptchd2 not found in the database. Append empty values.
# The gene Ptpla not found in the database. Append empty values.
# The gene Ptplad1 not found in the database. Append empty values.
# The gene Ptplad2 not found in the database. Append empty values.
# The gene Ptplb not found in the database. Append empty values.
# The gene Ptrf not found in the database. Append empty values.
# The gene Pvrl1 not found in the database. Append empty values.
# The gene Pvrl2 not found in the database. Append empty values.
# The gene Pvrl3 not found in the database. Append empty values.
# The gene Pvrl4 not found in the database. Append empty values.
# The gene Pydc3 not found in the database. Append empty values.
# The gene Pydc4 not found in the database. Append empty values.
# The gene Pyhin1 not found in the database. Append empty values.
# The gene Qtrtd1 not found in the database. Append empty values.
# The gene Rab1 not found in the database. Append empty values.
# The gene Rab11b-ps1 not found in the database. Append empty values.
# The gene Raver1-fdx1l not found in the database. Append empty values.
# The gene Rbpsuh-ps1 not found in the database. Append empty values.
# The gene Rbpsuh-ps2 not found in the database. Append empty values.
# The gene Rbpsuh-rs3 not found in the database. Append empty values.
# The gene Rfpl3s not found in the database. Append empty values.
# The gene Rfwd2 not found in the database. Append empty values.
# The gene Rgag1 not found in the database. Append empty values.
# The gene Rgag4 not found in the database. Append empty values.
# Multiple gene biotype exists for Rian. Merge the result.
# The gene Ric8 not found in the database. Append empty values.
# The gene Rltpr not found in the database. Append empty values.
# Multiple gene biotype exists for Rmrp. Merge the result.
# The gene Rn18s-rs5 not found in the database. Append empty values.
# The gene Rn4.5s-ps1 not found in the database. Append empty values.
# The gene Rn4.5s-ps2 not found in the database. Append empty values.
# The gene Rn4.5s-ps3 not found in the database. Append empty values.
# The gene Rnmtl1 not found in the database. Append empty values.
# The gene Rnr1 not found in the database. Append empty values.
# The gene Rnr2 not found in the database. Append empty values.
# The gene Rnu3b-ps2 not found in the database. Append empty values.
# The gene Rnu7-ps1 not found in the database. Append empty values.
# The gene Rp2h not found in the database. Append empty values.
# The gene Rpl19-ps8 not found in the database. Append empty values.
# The gene Rpl27a-ps3 not found in the database. Append empty values.
# The gene Rpl29-ps6 not found in the database. Append empty values.
# The gene Rpl30-ps7 not found in the database. Append empty values.
# The gene Rpl36-ps6 not found in the database. Append empty values.
# The gene Rps12l2 not found in the database. Append empty values.
# The gene Rps27-ps2 not found in the database. Append empty values.
# The gene Rqcd1 not found in the database. Append empty values.
# The gene Rsg1 not found in the database. Append empty values.
# The gene Rtfdc1 not found in the database. Append empty values.
# The gene Scn2a1 not found in the database. Append empty values.
# The gene Sdccag3 not found in the database. Append empty values.
# The gene Sdpr not found in the database. Append empty values.
# The gene Selk not found in the database. Append empty values.
# The gene Selm not found in the database. Append empty values.
# The gene Selo not found in the database. Append empty values.
# The gene Selt not found in the database. Append empty values.
# The gene Sep15 not found in the database. Append empty values.
# The gene Sepn1 not found in the database. Append empty values.
# The gene Sepp1 not found in the database. Append empty values.
# The gene Sept1 not found in the database. Append empty values.
# The gene Sept10 not found in the database. Append empty values.
# The gene Sept11 not found in the database. Append empty values.
# The gene Sept14 not found in the database. Append empty values.
# The gene Sept2 not found in the database. Append empty values.
# The gene Sept3 not found in the database. Append empty values.
# The gene Sept4 not found in the database. Append empty values.
# The gene Sept5 not found in the database. Append empty values.
# The gene Sept6 not found in the database. Append empty values.
# The gene Sept7 not found in the database. Append empty values.
# The gene Sept8 not found in the database. Append empty values.
# The gene Sept9 not found in the database. Append empty values.
# The gene Sepw1 not found in the database. Append empty values.
# The gene Setd8 not found in the database. Append empty values.
# The gene Sgol1 not found in the database. Append empty values.
# The gene Sgol2a not found in the database. Append empty values.
# The gene Sgol2b not found in the database. Append empty values.
# The gene Shfm1 not found in the database. Append empty values.
# The gene Skiv2l2 not found in the database. Append empty values.
# The gene Slc10a3-ubl4 not found in the database. Append empty values.
# The gene Slc22a13b-ps not found in the database. Append empty values.
# Multiple gene biotype exists for Slfn10-ps. Merge the result.
# The gene Slmo1 not found in the database. Append empty values.
# The gene Slmo2 not found in the database. Append empty values.
# The gene Smek1 not found in the database. Append empty values.
# The gene Smek2 not found in the database. Append empty values.
# The gene Smt3h2-ps3 not found in the database. Append empty values.
# Multiple gene biotype exists for Snhg4. Merge the result.
# The gene Snhg7 not found in the database. Append empty values.
# The gene Snord116 not found in the database. Append empty values.
# The gene Speer7-ps1 not found in the database. Append empty values.
# The gene Spin3 not found in the database. Append empty values.
# The gene Spt1 not found in the database. Append empty values.
# The gene Sqrdl not found in the database. Append empty values.
# The gene Ssfa2 not found in the database. Append empty values.
# The gene Sssca1 not found in the database. Append empty values.
# The gene St5 not found in the database. Append empty values.
# The gene Stmn1-rs2 not found in the database. Append empty values.
# The gene Stra13 not found in the database. Append empty values.
# The gene Stxbp3a not found in the database. Append empty values.
# The gene Stxbp3b not found in the database. Append empty values.
# The gene Suv420h1 not found in the database. Append empty values.
# The gene Suv420h2 not found in the database. Append empty values.
# The gene Taf4a not found in the database. Append empty values.
# The gene Tbrg3 not found in the database. Append empty values.
# The gene Tceb1 not found in the database. Append empty values.
# The gene Tceb2 not found in the database. Append empty values.
# The gene Tceb3 not found in the database. Append empty values.
# The gene Tcra not found in the database. Append empty values.
# The gene Tcrb not found in the database. Append empty values.
# The gene Tcrg not found in the database. Append empty values.
# The gene Tdpx-ps1 not found in the database. Append empty values.
# The gene Tenc1 not found in the database. Append empty values.
# Multiple gene biotype exists for Terc. Merge the result.
# The gene Tex13 not found in the database. Append empty values.
# The gene Tex40 not found in the database. Append empty values.
# The gene Tfdp1-ps not found in the database. Append empty values.
# The gene Tldc1 not found in the database. Append empty values.
# The gene Tmem110 not found in the database. Append empty values.
# The gene Tmem136 not found in the database. Append empty values.
# Multiple gene biotype exists for Tmem147os. Merge the result.
# The gene Tmem173 not found in the database. Append empty values.
# The gene Tmem180 not found in the database. Append empty values.
# The gene Tmem194 not found in the database. Append empty values.
# The gene Tmem194b not found in the database. Append empty values.
# The gene Tmem2 not found in the database. Append empty values.
# The gene Tmem206 not found in the database. Append empty values.
# The gene Tmem261 not found in the database. Append empty values.
# The gene Tmem35 not found in the database. Append empty values.
# The gene Tmem5 not found in the database. Append empty values.
# Multiple gene biotype exists for Tmem51os1. Merge the result.
# The gene Tmem55a not found in the database. Append empty values.
# The gene Tmem55b not found in the database. Append empty values.
# The gene Tmem56 not found in the database. Append empty values.
# The gene Tmem57 not found in the database. Append empty values.
# The gene Tmem8c not found in the database. Append empty values.
# The gene Tmevpg1 not found in the database. Append empty values.
# The gene Toporsos not found in the database. Append empty values.
# The gene Tpm3-rs3 not found in the database. Append empty values.
# Multiple gene biotype exists for Trerf1. Merge the result.
# The gene TrnA not found in the database. Append empty values.
# The gene TrnC not found in the database. Append empty values.
# The gene TrnD not found in the database. Append empty values.
# The gene TrnE not found in the database. Append empty values.
# The gene TrnF not found in the database. Append empty values.
# The gene TrnI not found in the database. Append empty values.
# The gene TrnL1 not found in the database. Append empty values.
# The gene TrnL2 not found in the database. Append empty values.
# The gene TrnM not found in the database. Append empty values.
# The gene TrnN not found in the database. Append empty values.
# The gene TrnP not found in the database. Append empty values.
# The gene TrnQ not found in the database. Append empty values.
# The gene TrnR not found in the database. Append empty values.
# The gene TrnS1 not found in the database. Append empty values.
# The gene TrnS2 not found in the database. Append empty values.
# The gene TrnT not found in the database. Append empty values.
# The gene TrnV not found in the database. Append empty values.
# The gene Trove2 not found in the database. Append empty values.
# The gene Trp53rk not found in the database. Append empty values.
# The gene Tssc1 not found in the database. Append empty values.
# The gene Tubb2a-ps1 not found in the database. Append empty values.
# The gene Tubb3-ps1 not found in the database. Append empty values.
# The gene Tusc5 not found in the database. Append empty values.
# The gene Ubl4 not found in the database. Append empty values.
# The gene Ufd1l not found in the database. Append empty values.
# The gene Usmg5 not found in the database. Append empty values.
# The gene Utp11l not found in the database. Append empty values.
# The gene Vimp not found in the database. Append empty values.
# The gene Vmn1r-ps87 not found in the database. Append empty values.
# Multiple gene biotype exists for Vmn2r-ps111. Merge the result.
# The gene Vmn2r-ps112 not found in the database. Append empty values.
# The gene Vmn2r-ps119 not found in the database. Append empty values.
# The gene Vmn2r-ps22 not found in the database. Append empty values.
# The gene Vmn2r-ps27 not found in the database. Append empty values.
# The gene Vmn2r-ps71 not found in the database. Append empty values.
# The gene Vmn2r-ps90 not found in the database. Append empty values.
# The gene Vprbp not found in the database. Append empty values.
# The gene Vwa9 not found in the database. Append empty values.
# The gene Wapal not found in the database. Append empty values.
# The gene Wash not found in the database. Append empty values.
# The gene Wbp5 not found in the database. Append empty values.
# The gene Wbscr16 not found in the database. Append empty values.
# The gene Wbscr17 not found in the database. Append empty values.
# The gene Wbscr22 not found in the database. Append empty values.
# The gene Wbscr27 not found in the database. Append empty values.
# The gene Whsc1 not found in the database. Append empty values.
# The gene Whsc1l1 not found in the database. Append empty values.
# The gene Wibg not found in the database. Append empty values.
# The gene Wisp1 not found in the database. Append empty values.
# The gene Wisp2 not found in the database. Append empty values.
# The gene Wisp3 not found in the database. Append empty values.
# The gene Wrb not found in the database. Append empty values.
# The gene Xrcc6bp1 not found in the database. Append empty values.
# The gene Zak not found in the database. Append empty values.
# The gene Zbed6 not found in the database. Append empty values.
# The gene Zcchc11 not found in the database. Append empty values.
# The gene Zcchc16 not found in the database. Append empty values.
# The gene Zcchc6 not found in the database. Append empty values.
# The gene Zfml not found in the database. Append empty values.
# The gene Zfp191 not found in the database. Append empty values.
# The gene Zfp33b not found in the database. Append empty values.
# The gene Zfp422-rs1 not found in the database. Append empty values.
# The gene Zfp607 not found in the database. Append empty values.
# Multiple gene biotype exists for Zfp813-ps. Merge the result.
# Multiple gene biotype exists for Zkscan7. Merge the result.
# The gene Znf157 not found in the database. Append empty values.
# The gene Znf512b not found in the database. Append empty values.
# The gene Znf660 not found in the database. Append empty values.
# The gene Zufsp not found in the database. Append empty values.
# The gene l7Rn6 not found in the database. Append empty values.
#
# There are 8662 genes not found and were skipped from this query.

# %%
Mop_gene_df = pd.DataFrame.from_dict(Mop_gene_dict)
Mop_gene_df = Mop_gene_df.set_index('gene')

Mop_gene_df
# Out:
#                 chr      start        end                   gene_biotype  \
# gene
# 0610005C13Rik     7   45567794   45575327                      antisense
# 0610007P14Rik  <NA>       <NA>       <NA>                           <NA>
# 0610009B22Rik    11   51685386   51688874                 protein_coding
# 0610009E02Rik     2   26445696   26459390           processed_transcript
# 0610009L18Rik    11  120348678  120351190  bidirectional_promoter_lncRNA
# ...             ...        ...        ...                            ...
# Zyx               6   42349630   42360213                 protein_coding
# Zzef1            11   72796226   72927120                 protein_coding
# Zzz3              3  152395473  152462826                 protein_coding
# a                 2  154791402  155051012                 protein_coding
# l7Rn6          <NA>       <NA>       <NA>                           <NA>
#
#               coding_strand
# gene
# 0610005C13Rik            -1
# 0610007P14Rik          <NA>
# 0610009B22Rik            -1
# 0610009E02Rik             1
# 0610009L18Rik             1
# ...                     ...
# Zyx                       1
# Zzef1                     1
# Zzz3                      1
# a                         1
# l7Rn6                  <NA>
#
# [33262 rows x 5 columns]

# %%
Mop_gene_df.dropna()
# Out:
#               chr      start        end                   gene_biotype  \
# gene
# 0610005C13Rik   7   45567794   45575327                      antisense
# 0610009B22Rik  11   51685386   51688874                 protein_coding
# 0610009E02Rik   2   26445696   26459390           processed_transcript
# 0610009L18Rik  11  120348678  120351190  bidirectional_promoter_lncRNA
# 0610010F05Rik  11   23564961   23633639                 protein_coding
# ...            ..        ...        ...                            ...
# Zyg11b          4  108229724  108301096                 protein_coding
# Zyx             6   42349630   42360213                 protein_coding
# Zzef1          11   72796226   72927120                 protein_coding
# Zzz3            3  152395473  152462826                 protein_coding
# a               2  154791402  155051012                 protein_coding
#
#               coding_strand
# gene
# 0610005C13Rik            -1
# 0610009B22Rik            -1
# 0610009E02Rik             1
# 0610009L18Rik             1
# 0610010F05Rik            -1
# ...                     ...
# Zyg11b                   -1
# Zyx                       1
# Zzef1                     1
# Zzz3                      1
# a                         1
#
# [24596 rows x 5 columns]

# %% [raw]
# # save the queried Mop gene df
#
# Mop_gene_df.to_csv(os.path.join(pool_folder, "MOp_smart_sn_gene_chr_info_NEW_from_transcriptome.csv"))

# %% [markdown]
# # 4. Add formated column for downstream analysis

# %%
# load gene annotation (covering all genes from the SMART-seq) for chr locus
#pool_folder = r'L:\Shiwei\DNA_MERFISH_analysis\SMARTer_nuclei_MOp'
#clean_gene_df = pd.read_csv(os.path.join(pool_folder, "MOp_smart_sn_gene_chr_info_NEW_from_transcriptome.csv"), index_col=0)

clean_gene_df = Mop_gene_df

# Append a column for gene length
clean_gene_df['length']=clean_gene_df['end']-clean_gene_df['start']
clean_gene_df=clean_gene_df.dropna()

clean_gene_df['start'] = clean_gene_df['start'].map(lambda x: int(x))
clean_gene_df['end'] = clean_gene_df['end'].map(lambda x: int(x))
clean_gene_df['length'] = clean_gene_df['length'].map(lambda x: int(x))

print(len(clean_gene_df))
clean_gene_df.head()
# Out:
# 24596
# <ipython-input-19-0009adc8161e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_gene_df['start'] = clean_gene_df['start'].map(lambda x: int(x))
# <ipython-input-19-0009adc8161e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_gene_df['end'] = clean_gene_df['end'].map(lambda x: int(x))
# <ipython-input-19-0009adc8161e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_gene_df['length'] = clean_gene_df['length'].map(lambda x: int(x))
#               chr      start        end                   gene_biotype  \
# gene
# 0610005C13Rik   7   45567794   45575327                      antisense
# 0610009B22Rik  11   51685386   51688874                 protein_coding
# 0610009E02Rik   2   26445696   26459390           processed_transcript
# 0610009L18Rik  11  120348678  120351190  bidirectional_promoter_lncRNA
# 0610010F05Rik  11   23564961   23633639                 protein_coding
#
#               coding_strand  length
# gene
# 0610005C13Rik            -1    7533
# 0610009B22Rik            -1    3488
# 0610009E02Rik             1   13694
# 0610009L18Rik             1    2512
# 0610010F05Rik            -1   68678

# %%
_gene_df['chr']
# Out:
# '7'

# %%
# add a genomic_position column to facilitate downstream analysis
_chr_loc_list = []
for _gene_df in clean_gene_df.iloc():
    _chr_loc = 'chr' + _gene_df['chr'] + '_' + str(_gene_df['start']) + '_' + str(_gene_df['end'])
    _chr_loc_list.append(_chr_loc)
    
    
    
clean_gene_df_new = clean_gene_df.copy()
clean_gene_df_new['genomic_position'] = _chr_loc_list

clean_gene_df_new
# Out:
#               chr      start        end                   gene_biotype  \
# gene
# 0610005C13Rik   7   45567794   45575327                      antisense
# 0610009B22Rik  11   51685386   51688874                 protein_coding
# 0610009E02Rik   2   26445696   26459390           processed_transcript
# 0610009L18Rik  11  120348678  120351190  bidirectional_promoter_lncRNA
# 0610010F05Rik  11   23564961   23633639                 protein_coding
# ...            ..        ...        ...                            ...
# Zyg11b          4  108229724  108301096                 protein_coding
# Zyx             6   42349630   42360213                 protein_coding
# Zzef1          11   72796226   72927120                 protein_coding
# Zzz3            3  152395473  152462826                 protein_coding
# a               2  154791402  155051012                 protein_coding
#
#               coding_strand  length           genomic_position
# gene
# 0610005C13Rik            -1    7533     chr7_45567794_45575327
# 0610009B22Rik            -1    3488    chr11_51685386_51688874
# 0610009E02Rik             1   13694     chr2_26445696_26459390
# 0610009L18Rik             1    2512  chr11_120348678_120351190
# 0610010F05Rik            -1   68678    chr11_23564961_23633639
# ...                     ...     ...                        ...
# Zyg11b                   -1   71372   chr4_108229724_108301096
# Zyx                       1   10583     chr6_42349630_42360213
# Zzef1                     1  130894    chr11_72796226_72927120
# Zzz3                      1   67353   chr3_152395473_152462826
# a                         1  259610   chr2_154791402_155051012
#
# [24596 rows x 7 columns]

# %%
# save the queried Mop gene df

clean_gene_df_new.to_csv(os.path.join(pool_folder, "MOp_smart_sn_gene_chr_info_NEW_from_transcriptome_FORMAT.csv"), index=True)

# %% [markdown]
# The scripts above can be used to generate gene annotation as in:
#
# [MOp_annotation_smart_seq](../../resources/MOp_smart_sn_gene_chr_info_NEW_from_transcriptome_FORMAT.csv)
#
# [MOp_annotation_10x](../../resources/MOp_10x_snRNA_chr_info_NEW_from_transcriptome_FORMAT.csv)
