# %% [markdown]
# # Analysis of DNA-MERFISH for CTP11,12,13
#
# by Pu Zheng
#
# 2022.07.07
#
# analysis for dataset:
#
# dna_data_folder = r'\\10.245.74.158\Chromatin_NAS_4\20220402-P_brain_CTP11-13_from_0329'
#
# rna_data_folder = r'\\10.245.74.158\Chromatin_NAS_0\20220329-P_brain_M1_nonclear_adaptors'
#
# save_folder = r'\\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp'

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 15660

# %% [markdown]
# ## 0.1 Folders

# %%
save_folder = r'\\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp'
save_filenames = [os.path.join(save_folder, _fl) for _fl in os.listdir(save_folder)
                  if _fl.split(os.extsep)[-1]=='hdf5']
# extract fov_id
save_fov_ids = [int(os.path.basename(_fl).split('.hdf5')[0].split('_')[-1]) for _fl in save_filenames]

debug = False

print(f"{len(save_filenames)} fovs detected")

analysis_folder = os.path.join(save_folder, 'Analysis_0709')

segmentation_folder = os.path.join(analysis_folder, 'Segmentation')
if not os.path.exists(segmentation_folder):
    os.makedirs(segmentation_folder)
    print(f"Creating segmentation_folder: {segmentation_folder}")
else:
    print(f"Use segmentation_folder: {segmentation_folder}")

cand_spot_folder = os.path.join(analysis_folder, 'CandSpots')
if not os.path.exists(cand_spot_folder):
    os.makedirs(cand_spot_folder)
    print(f"Creating cand_spot_folder: {cand_spot_folder}")
else:
    print(f"Use cand_spot_folder: {cand_spot_folder}")

decoder_folder = cand_spot_folder.replace('CandSpots', 'Decoder')
if debug:
    _version = 0
    while os.path.exists(os.path.join(decoder_folder, f'v{_version}')):
        _version += 1
    decoder_folder = os.path.join(decoder_folder, f'v{_version}')
if not os.path.exists(decoder_folder):
    os.makedirs(decoder_folder)
    print(f"Creating decoder_folder: {decoder_folder}")
else:
    print(f"Use decoder_folder: {decoder_folder}")
    
picked_folder = os.path.join(analysis_folder, 'Picked_v0')
if not os.path.exists(picked_folder):
    os.makedirs(picked_folder)
    print(f"Creating picked_folder: {picked_folder}")
else:
    print(f"Use picked_folder: {picked_folder}")
# Out:
# 161 fovs detected
# Use segmentation_folder: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation
# Use cand_spot_folder: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\CandSpots
# Use decoder_folder: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Decoder
# Use picked_folder: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Picked_v0

# %%
pixel_sizes = np.array([250,108,108])
single_im_size = np.array([50,2048,2048])

# %% [markdown]
# # 1. Partition DNA-MERFISH spots

# %%
from ImageAnalysis3.classes.partition_spots import Spots_Partition
from ImageAnalysis3.classes.preprocess import Spots3D
from ImageAnalysis3.figure_tools import plot_partition
import pandas as pd

# %%
from ImageAnalysis3.segmentation_tools.cell import Align_Segmentation
import ImageAnalysis3.io_tools.spots

# %%
search_radius = 3
overwrite_cand_spots = False
add_relabel_spots = False
data_type = 'combo' # 'combo'
#_total_seg_save_file defined in 2.3
if not os.path.exists(os.path.join(cand_spot_folder, data_type)):
    print(os.path.join(cand_spot_folder, data_type))
    os.makedirs(os.path.join(cand_spot_folder, data_type))
# load microscope.json
dna_microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
# Out:
# \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\CandSpots\combo

# %%
# %%time
_partition_args = []

for _fov_id, _save_filename in zip(save_fov_ids, save_filenames):

    _segmentation_savefile = os.path.join(segmentation_folder, 
        os.path.basename(_save_filename).replace('.hdf5', '_Segmentation.hdf5') )
    # savename
    _cand_spot_filename = os.path.join(cand_spot_folder, data_type, 
                                      os.path.basename(_save_filename).replace('.hdf5', f'_CandSpots.csv') )
    if os.path.isfile(_cand_spot_filename) and not overwrite_cand_spots:
        continue
    # load segmentation label matrix and uids
    _align_seg = Align_Segmentation('', '', _save_filename, '', dna_microscope_file, np.array([]))
    _align_seg._load(_segmentation_savefile)
    seg_label, fovcell_2_uid = _align_seg.dna_mask, _align_seg.fovcell_2_uid
    # load spots
    spots_list, combo_bits = ia.io_tools.spots.load_preprocess_spots(
        _save_filename, data_type, None, pixel_sizes=pixel_sizes,
    )
    # add relabeled spots if specified.
    if add_relabel_spots:
        relabel_spots_list, relabel_bits = ia.io_tools.spots.load_preprocess_spots(
            _save_filename, f'relabeled_{data_type}', None, pixel_sizes=pixel_sizes,
        )
        for _rspots, _rbit in zip(relabel_spots_list, relabel_bits):
            _ind = list(combo_bits).index(_rbit)
            _old_spots = spots_list[_ind]
            # merge
            _merged_spots = ia.io_tools.spots.merge_RelabelSpots(
                _old_spots, _rspots, pixel_sizes=pixel_sizes,
            )
            # replace
            spots_list[_ind] = _merged_spots
    # 
    _all_spots = ia.io_tools.spots.merge_Spots3DList(spots_list, pixel_sizes=pixel_sizes)
    # partition args
    _args = (
        _fov_id, 
        np.array(_all_spots), _all_spots.bits, _all_spots.channels,
        seg_label, fovcell_2_uid,
        dna_microscope_file,
        search_radius, pixel_sizes,
        True, 
        True, _cand_spot_filename,
        True, 60, 
        False, True,
    )
    _partition_args.append(_args)
    
print(len(_partition_args))
# Out:
# -- loading segmentation info from fov:0 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_000_Segmentation.hdf5
# -- loading segmentation info from fov:1 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_001_Segmentation.hdf5
# -- loading segmentation info from fov:2 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_002_Segmentation.hdf5
# -- loading segmentation info from fov:3 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_003_Segmentation.hdf5
# -- loading segmentation info from fov:4 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_004_Segmentation.hdf5
# -- loading segmentation info from fov:5 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_005_Segmentation.hdf5
# -- loading segmentation info from fov:6 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_006_Segmentation.hdf5
# -- loading segmentation info from fov:7 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_007_Segmentation.hdf5
# -- loading segmentation info from fov:8 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_008_Segmentation.hdf5
# -- loading segmentation info from fov:9 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_009_Segmentation.hdf5
# -- loading segmentation info from fov:10 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_010_Segmentation.hdf5
# -- loading segmentation info from fov:11 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_011_Segmentation.hdf5
# -- loading segmentation info from fov:12 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_012_Segmentation.hdf5
# -- loading segmentation info from fov:13 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_013_Segmentation.hdf5
# -- loading segmentation info from fov:14 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_014_Segmentation.hdf5
# -- loading segmentation info from fov:15 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_015_Segmentation.hdf5
# -- loading segmentation info from fov:16 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_016_Segmentation.hdf5
# -- loading segmentation info from fov:17 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_017_Segmentation.hdf5
# -- loading segmentation info from fov:18 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_018_Segmentation.hdf5
# -- loading segmentation info from fov:19 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_019_Segmentation.hdf5
# -- loading segmentation info from fov:20 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_020_Segmentation.hdf5
# -- loading segmentation info from fov:21 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_021_Segmentation.hdf5
# -- loading segmentation info from fov:22 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_022_Segmentation.hdf5
# -- loading segmentation info from fov:23 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_023_Segmentation.hdf5
# -- loading segmentation info from fov:24 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_024_Segmentation.hdf5
# -- loading segmentation info from fov:25 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_025_Segmentation.hdf5
# -- loading segmentation info from fov:26 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_026_Segmentation.hdf5
# -- loading segmentation info from fov:27 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_027_Segmentation.hdf5
# -- loading segmentation info from fov:28 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_028_Segmentation.hdf5
# -- loading segmentation info from fov:29 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_029_Segmentation.hdf5
# -- loading segmentation info from fov:30 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_030_Segmentation.hdf5
# -- loading segmentation info from fov:31 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_031_Segmentation.hdf5
# -- loading segmentation info from fov:32 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_032_Segmentation.hdf5
# -- loading segmentation info from fov:33 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_033_Segmentation.hdf5
# -- loading segmentation info from fov:34 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_034_Segmentation.hdf5
# -- loading segmentation info from fov:35 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_035_Segmentation.hdf5
# -- loading segmentation info from fov:36 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_036_Segmentation.hdf5
# -- loading segmentation info from fov:37 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_037_Segmentation.hdf5
# -- loading segmentation info from fov:38 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_038_Segmentation.hdf5
# -- loading segmentation info from fov:39 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_039_Segmentation.hdf5
# -- loading segmentation info from fov:40 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_040_Segmentation.hdf5
# -- loading segmentation info from fov:41 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_041_Segmentation.hdf5
# -- loading segmentation info from fov:42 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_042_Segmentation.hdf5
# -- loading segmentation info from fov:43 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_043_Segmentation.hdf5
# -- loading segmentation info from fov:44 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_044_Segmentation.hdf5
# -- loading segmentation info from fov:45 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_045_Segmentation.hdf5
# -- loading segmentation info from fov:46 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_046_Segmentation.hdf5
# -- loading segmentation info from fov:47 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_047_Segmentation.hdf5
# -- loading segmentation info from fov:48 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_048_Segmentation.hdf5
# -- loading segmentation info from fov:49 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_049_Segmentation.hdf5
# -- loading segmentation info from fov:50 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_050_Segmentation.hdf5
# -- loading segmentation info from fov:51 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_051_Segmentation.hdf5
# -- loading segmentation info from fov:52 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_052_Segmentation.hdf5
# -- loading segmentation info from fov:53 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_053_Segmentation.hdf5
# -- loading segmentation info from fov:54 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_054_Segmentation.hdf5
# -- loading segmentation info from fov:55 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_055_Segmentation.hdf5
# -- loading segmentation info from fov:56 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_056_Segmentation.hdf5
# -- loading segmentation info from fov:57 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_057_Segmentation.hdf5
# -- loading segmentation info from fov:58 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_058_Segmentation.hdf5
# -- loading segmentation info from fov:59 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_059_Segmentation.hdf5
# -- loading segmentation info from fov:60 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_060_Segmentation.hdf5
# -- loading segmentation info from fov:61 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_061_Segmentation.hdf5
# -- loading segmentation info from fov:62 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_062_Segmentation.hdf5
# -- loading segmentation info from fov:63 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_063_Segmentation.hdf5
# -- loading segmentation info from fov:64 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_064_Segmentation.hdf5
# -- loading segmentation info from fov:65 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_065_Segmentation.hdf5
# -- loading segmentation info from fov:66 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_066_Segmentation.hdf5
# -- loading segmentation info from fov:67 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_067_Segmentation.hdf5
# -- loading segmentation info from fov:68 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_068_Segmentation.hdf5
# -- loading segmentation info from fov:69 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_069_Segmentation.hdf5
# -- loading segmentation info from fov:70 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_070_Segmentation.hdf5
# -- loading segmentation info from fov:71 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_071_Segmentation.hdf5
# -- loading segmentation info from fov:72 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_072_Segmentation.hdf5
# -- loading segmentation info from fov:73 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_073_Segmentation.hdf5
# -- loading segmentation info from fov:74 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_074_Segmentation.hdf5
# -- loading segmentation info from fov:75 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_075_Segmentation.hdf5
# -- loading segmentation info from fov:76 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_076_Segmentation.hdf5
# -- loading segmentation info from fov:77 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_077_Segmentation.hdf5
# -- loading segmentation info from fov:78 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_078_Segmentation.hdf5
# -- loading segmentation info from fov:79 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_079_Segmentation.hdf5
# -- loading segmentation info from fov:80 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_080_Segmentation.hdf5
# -- loading segmentation info from fov:81 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_081_Segmentation.hdf5
# -- loading segmentation info from fov:82 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_082_Segmentation.hdf5
# -- loading segmentation info from fov:83 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_083_Segmentation.hdf5
# -- loading segmentation info from fov:84 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_084_Segmentation.hdf5
# -- loading segmentation info from fov:85 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_085_Segmentation.hdf5
# -- loading segmentation info from fov:86 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_086_Segmentation.hdf5
# -- loading segmentation info from fov:87 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_087_Segmentation.hdf5
# -- loading segmentation info from fov:88 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_088_Segmentation.hdf5
# -- loading segmentation info from fov:89 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_089_Segmentation.hdf5
# -- loading segmentation info from fov:90 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_090_Segmentation.hdf5
# -- loading segmentation info from fov:91 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_091_Segmentation.hdf5
# -- loading segmentation info from fov:92 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_092_Segmentation.hdf5
# -- loading segmentation info from fov:93 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_093_Segmentation.hdf5
# -- loading segmentation info from fov:94 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_094_Segmentation.hdf5
# -- loading segmentation info from fov:95 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_095_Segmentation.hdf5
# -- loading segmentation info from fov:96 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_096_Segmentation.hdf5
# -- loading segmentation info from fov:97 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_097_Segmentation.hdf5
# -- loading segmentation info from fov:98 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_098_Segmentation.hdf5
# -- loading segmentation info from fov:99 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_099_Segmentation.hdf5
# -- loading segmentation info from fov:100 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_100_Segmentation.hdf5
# -- loading segmentation info from fov:101 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_101_Segmentation.hdf5
# -- loading segmentation info from fov:102 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_102_Segmentation.hdf5
# -- loading segmentation info from fov:103 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_103_Segmentation.hdf5
# -- loading segmentation info from fov:104 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_104_Segmentation.hdf5
# -- loading segmentation info from fov:105 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_105_Segmentation.hdf5
# -- loading segmentation info from fov:106 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_106_Segmentation.hdf5
# -- loading segmentation info from fov:107 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_107_Segmentation.hdf5
# -- loading segmentation info from fov:108 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_108_Segmentation.hdf5
# -- loading segmentation info from fov:109 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_109_Segmentation.hdf5
# -- loading segmentation info from fov:110 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_110_Segmentation.hdf5
# -- loading segmentation info from fov:111 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_111_Segmentation.hdf5
# -- loading segmentation info from fov:112 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_112_Segmentation.hdf5
# -- loading segmentation info from fov:113 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_113_Segmentation.hdf5
# -- loading segmentation info from fov:114 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_114_Segmentation.hdf5
# -- loading segmentation info from fov:115 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_115_Segmentation.hdf5
# -- loading segmentation info from fov:116 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_116_Segmentation.hdf5
# -- loading segmentation info from fov:117 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_117_Segmentation.hdf5
# -- loading segmentation info from fov:118 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_118_Segmentation.hdf5
# -- loading segmentation info from fov:119 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_119_Segmentation.hdf5
# -- loading segmentation info from fov:120 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_120_Segmentation.hdf5
# -- loading segmentation info from fov:121 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_121_Segmentation.hdf5
# -- loading segmentation info from fov:122 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_122_Segmentation.hdf5
# -- loading segmentation info from fov:123 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_123_Segmentation.hdf5
# -- loading segmentation info from fov:124 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_124_Segmentation.hdf5
# -- loading segmentation info from fov:125 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_125_Segmentation.hdf5
# -- loading segmentation info from fov:126 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_126_Segmentation.hdf5
# -- loading segmentation info from fov:127 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_127_Segmentation.hdf5
# -- loading segmentation info from fov:128 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_128_Segmentation.hdf5
# -- loading segmentation info from fov:129 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_129_Segmentation.hdf5
# -- loading segmentation info from fov:130 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_130_Segmentation.hdf5
# -- loading segmentation info from fov:131 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_131_Segmentation.hdf5
# -- loading segmentation info from fov:132 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_132_Segmentation.hdf5
# -- loading segmentation info from fov:133 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_133_Segmentation.hdf5
# -- loading segmentation info from fov:134 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_134_Segmentation.hdf5
# -- loading segmentation info from fov:135 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_135_Segmentation.hdf5
# -- loading segmentation info from fov:136 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_136_Segmentation.hdf5
# -- loading segmentation info from fov:137 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_137_Segmentation.hdf5
# -- loading segmentation info from fov:138 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_138_Segmentation.hdf5
# -- loading segmentation info from fov:139 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_139_Segmentation.hdf5
# -- loading segmentation info from fov:140 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_140_Segmentation.hdf5
# -- loading segmentation info from fov:141 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_141_Segmentation.hdf5
# -- loading segmentation info from fov:142 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_142_Segmentation.hdf5
# -- loading segmentation info from fov:143 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_143_Segmentation.hdf5
# -- loading segmentation info from fov:144 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_144_Segmentation.hdf5
# -- loading segmentation info from fov:145 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_145_Segmentation.hdf5
# -- loading segmentation info from fov:146 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_146_Segmentation.hdf5
# -- loading segmentation info from fov:147 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_147_Segmentation.hdf5
# -- loading segmentation info from fov:148 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_148_Segmentation.hdf5
# -- loading segmentation info from fov:149 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_149_Segmentation.hdf5
# -- loading segmentation info from fov:150 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_150_Segmentation.hdf5
# -- loading segmentation info from fov:151 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_151_Segmentation.hdf5
# -- loading segmentation info from fov:152 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_152_Segmentation.hdf5
# -- loading segmentation info from fov:153 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_153_Segmentation.hdf5
# -- loading segmentation info from fov:154 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_154_Segmentation.hdf5
# -- loading segmentation info from fov:155 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_155_Segmentation.hdf5
# -- loading segmentation info from fov:156 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_156_Segmentation.hdf5
# -- loading segmentation info from fov:157 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_157_Segmentation.hdf5
# -- loading segmentation info from fov:158 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_158_Segmentation.hdf5
# -- loading segmentation info from fov:159 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_159_Segmentation.hdf5
# -- loading segmentation info from fov:160 into file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\Segmentation\Conv_zscan_160_Segmentation.hdf5
# 161
# Wall time: 19min 21s

# %% [markdown]
# ## 1.1 parallel process

# %%
# %%time
import multiprocessing as mp
# Multiprocessing
print(f"- Start multiprocessing spot partitioning", end=' ')
_start_time = time.time()
with mp.Pool(12) as _partition_pool:
    # start multiprocessing
    _partition_pool.starmap(ia.classes.partition_spots.batch_partition_DNA_spots, 
                            _partition_args, chunksize=1)
    # close multiprocessing
    _partition_pool.close()
    _partition_pool.join()
    _partition_pool.terminate()
print(f"finish in {time.time()-_start_time:.3f}s. ")
# Out:
# - Start multiprocessing spot partitioning finish in 3426.867s.
# Wall time: 57min 6s

# %% [markdown]
# ### 1.1.2 sequential version

# %%
# sequential
for _args in _partition_args:
    ia.classes.partition_spots.batch_partition_DNA_spots(*_args)
    break
# Out:
# - Partition cand_spots for fov:0
# -- partition barcodes for 1150120 spots
# 1150120it [01:00, 18949.95it/s]
# - Save 1150120 spots to file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220316-P_brain_CTP11-12-13_from_0304\Analysis_0706\CandSpots\combo\Conv_zscan_000_CandSpots.csv
# <img src="data:image/png;base64,..." width="599.9999869953505">
# -- save iamage to file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220316-P_brain_CTP11-12-13_from_0304\Analysis_0706\CandSpots\combo\Figures\Fov-0_SpotCountPerCell.png
# -- finish partition in 158.669s.

# %% [markdown]
# ## Partition sequential genes

# %%
search_radius = 3
overwrite_cand_spots = False
add_relabel_spots = False
data_type = 'unique'
expect_spot_num = 4

#_total_seg_save_file defined in 2.3
if not os.path.exists(os.path.join(cand_spot_folder,data_type)):
    print(os.path.join(cand_spot_folder,data_type))
    os.makedirs(os.path.join(cand_spot_folder,data_type))
# load microscope.json
dna_microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
# Out:
# \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220402-P_brain_CTP11-13_from_0329_warp\Analysis_0709\CandSpots\unique

# %%
# %%time
_partition_args = []

for _fov_id, _save_filename in zip(save_fov_ids, save_filenames):

    _segmentation_savefile = os.path.join(segmentation_folder, 
        os.path.basename(_save_filename).replace('.hdf5', '_Segmentation.hdf5') )
    # savename
    _cand_spot_filename = os.path.join(cand_spot_folder, data_type, 
                                      os.path.basename(_save_filename).replace('.hdf5', f'_CandSpots.csv') )
    if os.path.isfile(_cand_spot_filename) and not overwrite_cand_spots:
        continue
    # load segmentation label matrix and uids
    _align_seg = Align_Segmentation('', '', _save_filename, '', dna_microscope_file, np.array([]))
    _align_seg._load(_segmentation_savefile)
    seg_label, fovcell_2_uid = _align_seg.dna_mask, _align_seg.fovcell_2_uid
    # load spots
    spots_list, combo_bits = ia.io_tools.spots.load_preprocess_spots(
        _save_filename, data_type, None, pixel_sizes=pixel_sizes,
    )
    # add relabeled spots if specified.
    if add_relabel_spots:
        relabel_spots_list, relabel_bits = ia.io_tools.spots.load_preprocess_spots(
            _save_filename, f'relabeled_{data_type}', None, pixel_sizes=pixel_sizes,
        )
        for _rspots, _rbit in zip(relabel_spots_list, relabel_bits):
            _ind = list(combo_bits).index(_rbit)
            _old_spots = spots_list[_ind]
            # merge
            _merged_spots = ia.io_tools.spots.merge_RelabelSpots(
                _old_spots, _rspots, pixel_sizes=pixel_sizes,
            )
            # replace
            spots_list[_ind] = _merged_spots
    # 
    _all_spots = ia.io_tools.spots.merge_Spots3DList(spots_list, pixel_sizes=pixel_sizes)
    # partition args
    _args = (
        _fov_id, 
        np.array(_all_spots), _all_spots.bits, _all_spots.channels,
        seg_label, fovcell_2_uid,
        dna_microscope_file,
        search_radius, pixel_sizes,
        True, 
        True, _cand_spot_filename,
        True, expect_spot_num, 
        False, True,
    )
    _partition_args.append(_args)
    
print(len(_partition_args))
# Out:
# 0
# Wall time: 142 ms

# %%
# %%time
import multiprocessing as mp
# Multiprocessing
print(f"- Start multiprocessing spot partitioning", end=' ')
_start_time = time.time()
with mp.Pool(12) as _partition_pool:
    # start multiprocessing
    _partition_pool.starmap(ia.classes.partition_spots.batch_partition_DNA_spots, 
                            _partition_args, chunksize=1)
    # close multiprocessing
    _partition_pool.close()
    _partition_pool.join()
    _partition_pool.terminate()
print(f"finish in {time.time()-_start_time:.3f}s. ")
# Out:
# - Start multiprocessing spot partitioning
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "E:\Users\puzheng\Documents\ImageAnalysis3\classes\partition_spots.py", line 390, in batch_partition_DNA_spots
#     count_ax = plot_cell_spot_counts(cell_spot_counts, expected_count=expected_count, save_filename=SpotCount_SaveFile)
#   File "E:\Users\puzheng\Documents\ImageAnalysis3\figure_tools\plot_partition.py", line 19, in plot_cell_spot_counts
#     _pf = ax.imshow(cell_spot_counts, cmap='Spectral_r', vmin=0, vmax=expected_count)
#   File "E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\__init__.py", line 1361, in inner
#     return func(ax, *map(sanitize_sequence, args), **kwargs)
#   File "E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\axes\_axes.py", line 5609, in imshow
#     im.set_data(X)
#   File "E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\image.py", line 709, in set_data
#     raise TypeError("Invalid shape {} for image data"
# TypeError: Invalid shape (0,) for image data
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py in starmap(self, func, iterable, chunksize)
#     370         `func` and (a, b) becomes func(a, b).
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#     374     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py in worker()
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\multiprocessing\pool.py in starmapstar()
#      49
#      50 def starmapstar(args):
# ---> 51     return list(itertools.starmap(args[0], args[1]))
#      52
#      53 #
#
# E:\Users\puzheng\Documents\ImageAnalysis3\classes\partition_spots.py in batch_partition_DNA_spots()
#     388             if not os.path.exists(os.path.dirname(SpotCount_SaveFile)):
#     389                 os.makedirs(os.path.dirname(SpotCount_SaveFile))
# --> 390             count_ax = plot_cell_spot_counts(cell_spot_counts, expected_count=expected_count, save_filename=SpotCount_SaveFile)
#     391         if verbose:
#     392             print(f"-- finish partition in {time.time()-_start_time:.3f}s. ")
#
# E:\Users\puzheng\Documents\ImageAnalysis3\figure_tools\plot_partition.py in plot_cell_spot_counts()
#      17     fig, ax = plt.subplots(figsize=_figsize, dpi=_dpi, )
#      18
# ---> 19     _pf = ax.imshow(cell_spot_counts, cmap='Spectral_r', vmin=0, vmax=expected_count)
#      20
#      21     ax.tick_params('both', labelsize=8,
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\__init__.py in inner()
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\axes\_axes.py in imshow()
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# E:\Users\puzheng\anaconda3\envs\ia3_postanalysis\lib\site-packages\matplotlib\image.py in set_data()
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (0,) for image data

# %% [markdown]
# ### 1.2.2 sequential version

# %%
# sequential
for _args in _partition_args:
    ia.classes.partition_spots.batch_partition_DNA_spots(*_args)
    break
# Out:
# - Partition cand_spots for fov:0
# -- partition barcodes for 44295 spots
# 44295it [00:02, 19146.82it/s]
# - Save 44295 spots to file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220316-P_brain_CTP11-12-13_from_0304\Analysis_0706\CandSpots\unique\Conv_zscan_000_CandSpots.csv
# <img src="data:image/png;base64,..." width="599.9999869953505">
# -- save iamage to file: \\10.245.74.158\Chromatin_NAS_8\Analyzed_data\20220316-P_brain_CTP11-12-13_from_0304\Analysis_0706\CandSpots\unique\Figures\Fov-0_SpotCountPerCell.png
# -- finish partition in 6.648s.
