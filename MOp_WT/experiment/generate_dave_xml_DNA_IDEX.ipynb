# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os

valve_start =  1   #1 + 8 #19 + 9 
# H
hyb_start = 1+24+24 #67 # hyb1 skip 
# R
reg_start = 2+24+24 #26 

num_rounds = 22

add_ref_hyb = False

#data_type = 'L'
data_type = 'C'

valve_ids = np.arange(valve_start, valve_start + num_rounds)
hyb_ids = np.arange(hyb_start, hyb_start + num_rounds)
reg_names = [f'{data_type}{_i}' for _i in np.arange(reg_start, reg_start + num_rounds)]

# %%
source_folder = r'D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2'

#target_drive = r'\\10.245.74.158\Chromatin_NAS_5'
target_drive = r'\\10.245.74.158\Chromatin_NAS_1'

# imaging protocol
imaging_protocol = r'Zscan_750_647_561_488_s50_n250_10Hz'

# reference imaging protocol
ref_imaging_protocol = r'Zscan_750_647_561_488_405_s50_n250_10Hz'
ref_hyb = 0
# bleach protocol
bleach = True
bleach_protocol = r'Bleach_750_647_561_s5'

add_10min_after_bleach = False

# %%
cmd_seq = Element('command_sequence')

if add_ref_hyb:
    # add hyb 0
    # comments
    comment = Comment(f"Hyb 0")
    cmd_seq.append(comment)
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"

    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H0{data_type}1")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "15000"

    # imaging loop
    _im_p = ref_imaging_protocol

    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text 
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"


for _i, (_vid, _hid, _rname) in enumerate(zip(valve_ids, hyb_ids, reg_names)):
    # select protocol
    _im_p = imaging_protocol
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "Flow TCEP"
    # wash tcep
    tcep_wash = SubElement(cmd_seq, 'valve_protocol')
    tcep_wash.text = "Flow Wash Buffer"
        
    # comments
    comment = Comment(f"Hyb {_hid} with valve {_vid} for {_rname}")
    cmd_seq.append(comment)
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    if bleach:
        # delay time
        delay = SubElement(cmd_seq, 'delay')
        delay.text = "3000"
        # change directory
        bleach_change_dir = SubElement(cmd_seq, 'change_directory')
        bleach_change_dir.text = os.path.join(source_folder, f"Bleach")
        # wakeup
        bleach_wakeup = SubElement(cmd_seq, 'wakeup')
        bleach_wakeup.text = "15000"
        # imaging loop
        bleach_loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
        bleach_loop_item = SubElement(bleach_loop, 'item', name=bleach_protocol)
        bleach_loop_item.text = " "
        # delay time
        delay = SubElement(cmd_seq, 'delay')
        delay.text = "3000"
        # if add incubation after bleach
        if add_10min_after_bleach:
            # delay time
            adt_incubation = SubElement(cmd_seq, 'valve_protocol')
            adt_incubation.text = f"Incubate 10min"
               
    else:
        # delay time
        adt_incubation = SubElement(cmd_seq, 'valve_protocol')
        adt_incubation.text = f"Incubate 10min"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Flow Wash Buffer"
    
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    readouts.text = "Flow RNA common readouts"
    # incubate readouts
    readout_incubation = SubElement(cmd_seq, 'valve_protocol')
    readout_incubation.text = f"Incubate 10min"
    # wash readouts
    readout_wash = SubElement(cmd_seq, 'valve_protocol')
    readout_wash.text = f"Flow Wash Buffer"
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"
    
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "15000"
    
    # imaging loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)

final_str = prettify(cmd_seq)
    
print( final_str )
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 49 with valve 1 for C50-->
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H49C50</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H49C50</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H49C50</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 50 with valve 2 for C51-->
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H50C51</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H50C51</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H50C51</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 51 with valve 3 for C52-->
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H51C52</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H51C52</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H51C52</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 52 with valve 4 for C53-->
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H52C53</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H52C53</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H52C53</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 53 with valve 5 for C54-->
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H53C54</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H53C54</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H53C54</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 54 with valve 6 for C55-->
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H54C55</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H54C55</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H54C55</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 55 with valve 7 for C56-->
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H55C56</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H55C56</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H55C56</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 56 with valve 8 for C57-->
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H56C57</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H56C57</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H56C57</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 57 with valve 9 for C58-->
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H57C58</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H57C58</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H57C58</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 58 with valve 10 for C59-->
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H58C59</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H58C59</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H58C59</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 59 with valve 11 for C60-->
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H59C60</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H59C60</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H59C60</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 60 with valve 12 for C61-->
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H60C61</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H60C61</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H60C61</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 61 with valve 13 for C62-->
# 	<valve_protocol>Hybridize 13</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H61C62</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H61C62</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H61C62</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 62 with valve 14 for C63-->
# 	<valve_protocol>Hybridize 14</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H62C63</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H62C63</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H62C63</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 63 with valve 15 for C64-->
# 	<valve_protocol>Hybridize 15</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H63C64</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H63C64</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H63C64</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 64 with valve 16 for C65-->
# 	<valve_protocol>Hybridize 16</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H64C65</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H64C65</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H64C65</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 65 with valve 17 for C66-->
# 	<valve_protocol>Hybridize 17</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H65C66</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H65C66</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H65C66</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 66 with valve 18 for C67-->
# 	<valve_protocol>Hybridize 18</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H66C67</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H66C67</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H66C67</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 67 with valve 19 for C68-->
# 	<valve_protocol>Hybridize 19</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H67C68</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H67C68</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H67C68</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 68 with valve 20 for C69-->
# 	<valve_protocol>Hybridize 20</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H68C69</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H68C69</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H68C69</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 69 with valve 21 for C70-->
# 	<valve_protocol>Hybridize 21</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H69C70</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H69C70</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H69C70</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 70 with valve 22 for C71-->
# 	<valve_protocol>Hybridize 22</valve_protocol>
# 	<delay>3000</delay>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\Bleach</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Bleach_750_647_561_s5"> </item>
# 	</loop>
# 	<delay>3000</delay>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H70C71</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\H70C71</source_path>
# 		<target_path>\\10.245.74.158\Chromatin_NAS_1\20230406-hM1_CTP14_from_Cx28_sample2\H70C71</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# </command_sequence>

# %% [markdown]
# # save this xml

# %%
source_folder
# Out:
# 'D:\\Shiwei\\20230406-hM1_CTP14_from_Cx28_sample2'

# %%
save_filename = os.path.join(source_folder, f"generated_dave_H{hyb_start}-{hyb_start+num_rounds-1}.txt")
with open(save_filename, 'w') as _output_handle:
    print(save_filename)
    _output_handle.write(final_str)
# Out:
# D:\Shiwei\20230406-hM1_CTP14_from_Cx28_sample2\generated_dave_H49-70.txt
