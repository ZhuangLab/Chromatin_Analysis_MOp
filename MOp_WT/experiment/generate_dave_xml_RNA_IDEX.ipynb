# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os

valve_start = 1

hyb_start = 1

reg_start = 2

num_rounds = 18

add_ref_hyb = True

#data_type = 'R'
data_type = 'M'

valve_ids = np.arange(valve_start, valve_start + num_rounds)
hyb_ids = np.arange(hyb_start, hyb_start + num_rounds)
reg_names = [f'{data_type}{_i}' for _i in np.arange(reg_start, reg_start + num_rounds)]

# %%
source_folder = r'D:\Pu\20220304-P_brain_M1_nonclear_adaptors'
target_drive = r'\\KOLMOGOROV\Chromatin_NAS_0'
imaging_protocol = r'Conv_Zscan_750_647_561_s13_n1000_5Hz'
#imaging_protocol = r'Conv_Zscan_750_s13_647_s13_560_s1_405_s1_n1000_5Hz'
ref_imaging_protocol = r'Conv_Zscan_750_647_561_488_405_s50_n250_5Hz'
ref_hyb = 0

# %%
cmd_seq = Element('command_sequence')

if add_ref_hyb:
    # add hyb 0
    # comments
    comment = Comment(f"Hyb 0")
    cmd_seq.append(comment)
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"

    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H0{data_type}1")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"

    # imaging loop
    _im_p = ref_imaging_protocol

    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text 
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"


for _i, (_vid, _hid, _rname) in enumerate(zip(valve_ids, hyb_ids, reg_names)):
    
    # select protocol
    if _hid == ref_hyb:
        _im_p = ref_imaging_protocol
    else:
        _im_p = imaging_protocol
    
    if _hid > 0:
        # TCEP
        tcep = SubElement(cmd_seq, 'valve_protocol')
        tcep.text = "Flow TCEP"
        # wash tcep
        tcep_wash = SubElement(cmd_seq, 'valve_protocol')
        tcep_wash.text = "Flow 2xSSC"
        
    # comments
    comment = Comment(f"Hyb {_hid} with {_vid} for {_rname}")
    cmd_seq.append(comment)
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'valve_protocol')
    adt_incubation.text = f"Incubate 15min"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Flow Wash Buffer"
    
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"
    
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    
    # imaging loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)

ssc = SubElement(cmd_seq, 'valve_protocol')
ssc.text = f"Flow 2xSSC"

final_str = prettify(cmd_seq)
    
print( final_str )
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 0-->
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H0M1</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_488_405_s50_n250_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H0M1</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H0M1</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 1 with 1 for M2-->
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H1M2</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H1M2</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H1M2</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 2 with 2 for M3-->
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H2M3</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H2M3</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H2M3</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 3 with 3 for M4-->
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H3M4</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H3M4</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H3M4</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 4 with 4 for M5-->
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H4M5</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H4M5</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H4M5</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 5 with 5 for M6-->
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H5M6</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H5M6</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H5M6</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 6 with 6 for M7-->
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H6M7</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H6M7</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H6M7</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 7 with 7 for M8-->
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H7M8</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H7M8</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H7M8</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 8 with 8 for M9-->
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H8M9</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H8M9</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H8M9</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 9 with 9 for M10-->
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H9M10</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H9M10</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H9M10</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 10 with 10 for M11-->
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H10M11</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H10M11</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H10M11</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 11 with 11 for M12-->
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H11M12</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H11M12</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H11M12</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 12 with 12 for M13-->
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H12M13</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H12M13</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H12M13</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 13 with 13 for M14-->
# 	<valve_protocol>Hybridize 13</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H13M14</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H13M14</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H13M14</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 14 with 14 for M15-->
# 	<valve_protocol>Hybridize 14</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H14M15</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H14M15</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H14M15</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 15 with 15 for M16-->
# 	<valve_protocol>Hybridize 15</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H15M16</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H15M16</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H15M16</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 16 with 16 for M17-->
# 	<valve_protocol>Hybridize 16</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H16M17</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H16M17</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H16M17</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 17 with 17 for M18-->
# 	<valve_protocol>Hybridize 17</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H17M18</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H17M18</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H17M18</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<!--Hyb 18 with 18 for M19-->
# 	<valve_protocol>Hybridize 18</valve_protocol>
# 	<valve_protocol>Incubate 15min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20220226-P_brain_M1_nonclear\H18M19</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Conv_Zscan_750_647_561_s13_n1000_5Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20220226-P_brain_M1_nonclear\H18M19</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_0\20220226-P_brain_M1_nonclear\H18M19</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# </command_sequence>

# %% [markdown]
# # save this xml

# %%
save_filename = os.path.join(source_folder, f"generated_dave_H{hyb_start}-{hyb_start+num_rounds-1}.txt")
with open(save_filename, 'w') as _output_handle:
    print(save_filename)
    _output_handle.write(final_str)
# Out:
# D:\Pu\20220226-P_brain_M1_nonclear\generated_dave_H1-18.txt

# %%
11.6/(1885 / (500/60 * 160))
# Out:
# 8.205128205128206

# %%
1885/160
# Out:
# 11.78125
